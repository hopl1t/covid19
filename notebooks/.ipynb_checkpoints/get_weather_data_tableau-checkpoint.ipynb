# %%
import urllib
import json
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
from keys import client_id, client_secret, app_id

# %% [markdown]
# Datasource:
# https://docs.google.com/spreadsheets/d/14quQPFErG-hlpsrNgYcX85vW7JMMK5X2vNZrafRcH8c/edit?usp=sharing

# %%
data = pd.read_csv('../original_datasets/tableau_time_sereis0403.csv')

# %%
states = data['Province_State'].unique().tolist()
dates = data['Date'].unique().tolist()
coords = data.groupby(['Lat', 'Long']).size().index.tolist()
data['avg_tmp'] = np.nan
data['avg_RH'] = np.nan
data['avg_wind'] = np.nan
data['avg_precip'] = np.nan
# data['avg_d_sun'] = np.nan
data['avg_m_tmp'] = np.nan
data['avg_m_RH'] = np.nan
data['avg_m_wind'] = np.nan
data['avg_m_precip'] = np.nan

# %%
start = date_range[0].strftime('%m/%d/%Y')
for date in date_range[5:][::5]:
    end = date.strftime('%m/%d/%Y')
    print(start + ' ' + end)
    start = end
# Out:
# 01/01/2020 01/06/2020
# 01/06/2020 01/11/2020
# 01/11/2020 01/16/2020
# 01/16/2020 01/21/2020
# 01/21/2020 01/26/2020
# 01/26/2020 01/31/2020
# 01/31/2020 02/05/2020
# 02/05/2020 02/10/2020
# 02/10/2020 02/15/2020
# 02/15/2020 02/20/2020
# 02/20/2020 02/25/2020
# 02/25/2020 03/01/2020
# 03/01/2020 03/06/2020
# 03/06/2020 03/11/2020
# 03/11/2020 03/16/2020
# 03/16/2020 03/21/2020
# 03/21/2020 03/26/2020
# 03/26/2020 03/31/2020

# %%
# set for up to 30 days a time
# START_TIME = '03/01/2020'
# END_TIME = '04/01/2020'
RADIUS = 350
INTERVAL = 5
q = 0

date_range = pd.date_range('2020-01-01', periods=95, freq='D')
start_time = date_range[0].strftime('%m/%d/%Y')

with open('weather_logs/tableau_log{0}.txt'.format(datetime.now().strftime('%d%m%Y')), 'w') as log:
    msg = 'Start date: {0}\nEnd date: {1}\nInterval:{2}'.format(start_time, date_range[-1]..strftime('%m/%d/%Y'), INTERVAL)
    print(msg)

    for date in date_range[INTERVAL:][::INTERVAL]:
        end_time = date.strftime('%m/%d/%Y')    
        for coord in coords:
            q += 1
            lat = coord[0]
            long = coord[1]
            location = data.loc[data['Lat'] == lat]\
                            .loc[data['Long'] == long]\
                             [['Country_Region','Province_State']]
            country = location.iloc[0][0]
            province = location.iloc[0][1]
            url = 'https://api.aerisapi.com/observations/summary/closest?p={0},{1}&from={2}&to={3}&radius={4}miles&plimit=31&limit=1&'\
                  'client_id={5}&client_secret={6}'.format(lat, long, start_time, end_time, RADIUS, client_id, client_secret)
            msg = 'collecting for {0} location {1}, {2}\n{3}'.format(q, province, country, url)
            print(msg)
            log.write(msg+'\n')
            request = urllib.request.urlopen(url)
            response = request.read()
            json_ = json.loads(response)
            if json_['success']: 
                print('success')
                log.write('success\n')
                try:
                    for day in json_['response'][0]['periods']:
                        date = datetime.strptime(str(day['summary']['ymd']), '%Y%m%d').strftime("%-m/%-d/%Y")
                        print(date)
                        for index in data.loc[data['Date'] == date]\
                                         .loc[data['Lat'] == coord[0]]\
                                         .loc[data['Long'] == coord[1]].index:
                            data.at[index, 'avg_d_tmp'] = day['summary']['temp']['avgC']
                            data.at[index, 'avg_d_RH'] = day['summary']['rh']['avg']
                            data.at[index, 'avg_d_wind'] = day['summary']['wind']['avgKPH']
                            data.at[index, 'avg_d_precip'] = day['summary']['precip']['totalMM']
                except IndexError:
                    if json_['error']:
                        msg = 'No data found for {0}, {1} at {2}\n{3}\r\n'.format(country, province, date, json_['error'])
                        print(msg)
                        log.write(msg)
                except Exception:
                    msg = 'Unknowen error\n{0}\r\n'.format(json_['error'])
                    print(msg)
                    log.write(msg)
                finally:
                    request.close()
    start_time = end_time
# Out:
# collecting for 1 location Tasmania, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-41.4545,145.9707&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 2 location nan, New Zealand
# https://api.aerisapi.com/observations/summary/closest?p=-40.9006,174.886&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3 location nan, Argentina
# https://api.aerisapi.com/observations/summary/closest?p=-38.4161,-63.6167&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 4 location Victoria, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-37.8136,144.9631&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 5 location nan, Chile
# https://api.aerisapi.com/observations/summary/closest?p=-35.6751,-71.543&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 6 location Australian Capital Territory, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-35.4735,149.0124&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 7 location South Australia, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-34.9285,138.6007&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 8 location New South Wales, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-33.8688,151.2093&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 9 location nan, Uruguay
# https://api.aerisapi.com/observations/summary/closest?p=-32.5228,-55.7658&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 10 location Western Australia, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-31.9505,115.8605&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 11 location nan, South Africa
# https://api.aerisapi.com/observations/summary/closest?p=-30.5595,22.9375&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 12 location Queensland, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-28.0167,153.4&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 13 location nan, Eswatini
# https://api.aerisapi.com/observations/summary/closest?p=-26.5225,31.4659&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 14 location nan, Paraguay
# https://api.aerisapi.com/observations/summary/closest?p=-23.4425,-58.4438&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 15 location nan, Namibia
# https://api.aerisapi.com/observations/summary/closest?p=-22.9576,18.4904&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 16 location nan, Botswana
# https://api.aerisapi.com/observations/summary/closest?p=-22.3285,24.6849&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 17 location Reunion, France
# https://api.aerisapi.com/observations/summary/closest?p=-21.1351,55.2471&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 18 location New Caledonia, France
# https://api.aerisapi.com/observations/summary/closest?p=-20.9043,165.618&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 19 location nan, Mauritius
# https://api.aerisapi.com/observations/summary/closest?p=-20.2,57.5&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 20 location nan, Zimbabwe
# https://api.aerisapi.com/observations/summary/closest?p=-20.0,30.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 21 location nan, Madagascar
# https://api.aerisapi.com/observations/summary/closest?p=-18.7669,46.8691&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 22 location nan, Mozambique
# https://api.aerisapi.com/observations/summary/closest?p=-18.665695,35.529562&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 23 location nan, Fiji
# https://api.aerisapi.com/observations/summary/closest?p=-17.7134,178.065&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 24 location French Polynesia, France
# https://api.aerisapi.com/observations/summary/closest?p=-17.6797,149.4068&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 25 location nan, Bolivia
# https://api.aerisapi.com/observations/summary/closest?p=-16.2902,-63.5887&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 26 location nan, Zambia
# https://api.aerisapi.com/observations/summary/closest?p=-15.4167,28.2833&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 27 location American Samoa, US
# https://api.aerisapi.com/observations/summary/closest?p=-14.270999999999999,-170.132&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 28 location nan, Brazil
# https://api.aerisapi.com/observations/summary/closest?p=-14.235,-51.9253&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 29 location nan, Malawi
# https://api.aerisapi.com/observations/summary/closest?p=-13.254307999999998,34.301525&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 30 location Mayotte, France
# https://api.aerisapi.com/observations/summary/closest?p=-12.8275,45.1662&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 31 location Northern Territory, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-12.4634,130.8456&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 32 location nan, Angola
# https://api.aerisapi.com/observations/summary/closest?p=-11.2027,17.8739&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 33 location nan, Peru
# https://api.aerisapi.com/observations/summary/closest?p=-9.19,-75.0152&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 34 location nan, Timor-Leste
# https://api.aerisapi.com/observations/summary/closest?p=-8.874217,125.727539&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 35 location nan, Tanzania
# https://api.aerisapi.com/observations/summary/closest?p=-6.369,34.8888&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 36 location nan, Papua New Guinea
# https://api.aerisapi.com/observations/summary/closest?p=-6.315,143.9555&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 37 location nan, Seychelles
# https://api.aerisapi.com/observations/summary/closest?p=-4.6796,55.492&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 38 location nan, Congo (Brazzaville)
# https://api.aerisapi.com/observations/summary/closest?p=-4.0383,21.7587&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 39 location nan, Burundi
# https://api.aerisapi.com/observations/summary/closest?p=-3.3731,29.9189&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 40 location nan, Rwanda
# https://api.aerisapi.com/observations/summary/closest?p=-1.9403,29.8739&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 41 location nan, Ecuador
# https://api.aerisapi.com/observations/summary/closest?p=-1.8312,-78.1834&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 42 location nan, Gabon
# https://api.aerisapi.com/observations/summary/closest?p=-0.8037,11.6094&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 43 location nan, Indonesia
# https://api.aerisapi.com/observations/summary/closest?p=-0.7893,113.9213&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 44 location nan, Kenya
# https://api.aerisapi.com/observations/summary/closest?p=-0.0236,37.9062&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 45 location Nevada, US
# https://api.aerisapi.com/observations/summary/closest?p=0.0,0.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 46 location nan, Uganda
# https://api.aerisapi.com/observations/summary/closest?p=1.0,32.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 47 location nan, Singapore
# https://api.aerisapi.com/observations/summary/closest?p=1.2833,103.8333&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 48 location nan, Equatorial Guinea
# https://api.aerisapi.com/observations/summary/closest?p=1.5,10.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 49 location nan, Malaysia
# https://api.aerisapi.com/observations/summary/closest?p=2.5,112.5&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 50 location nan, Maldives
# https://api.aerisapi.com/observations/summary/closest?p=3.2028,73.2207&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 51 location nan, Cameroon
# https://api.aerisapi.com/observations/summary/closest?p=3.8480000000000003,11.5021&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 52 location nan, Suriname
# https://api.aerisapi.com/observations/summary/closest?p=3.9193,-56.0278&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 53 location French Guiana, France
# https://api.aerisapi.com/observations/summary/closest?p=3.9339,-53.1258&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 54 location nan, Brunei
# https://api.aerisapi.com/observations/summary/closest?p=4.5353,114.7277&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 55 location nan, Colombia
# https://api.aerisapi.com/observations/summary/closest?p=4.5709,-74.2973&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 56 location nan, Guyana
# https://api.aerisapi.com/observations/summary/closest?p=5.0,-58.75&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 57 location nan, Somalia
# https://api.aerisapi.com/observations/summary/closest?p=5.1521,46.1996&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 58 location nan, Venezuela
# https://api.aerisapi.com/observations/summary/closest?p=6.4238,-66.5897&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 59 location nan, Liberia
# https://api.aerisapi.com/observations/summary/closest?p=6.4281,-9.4295&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 60 location nan, Central African Republic
# https://api.aerisapi.com/observations/summary/closest?p=6.6111,20.9394&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 61 location nan, Sri Lanka
# https://api.aerisapi.com/observations/summary/closest?p=7.0,81.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 62 location nan, Cote d'Ivoire
# https://api.aerisapi.com/observations/summary/closest?p=7.54,-5.5471&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 63 location nan, Ghana
# https://api.aerisapi.com/observations/summary/closest?p=7.9465,-1.0232&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 64 location nan, Sierra Leone
# https://api.aerisapi.com/observations/summary/closest?p=8.460555000000001,-11.779889&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 65 location nan, Panama
# https://api.aerisapi.com/observations/summary/closest?p=8.538,-80.7821&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 66 location nan, Togo
# https://api.aerisapi.com/observations/summary/closest?p=8.6195,0.8248&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 67 location nan, Nigeria
# https://api.aerisapi.com/observations/summary/closest?p=9.082,8.6753&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 68 location nan, Ethiopia
# https://api.aerisapi.com/observations/summary/closest?p=9.145,40.4897&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 69 location nan, Benin
# https://api.aerisapi.com/observations/summary/closest?p=9.3077,2.3158&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 70 location nan, Costa Rica
# https://api.aerisapi.com/observations/summary/closest?p=9.7489,-83.7534&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 71 location nan, Guinea
# https://api.aerisapi.com/observations/summary/closest?p=9.9456,-9.6966&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 72 location nan, Trinidad and Tobago
# https://api.aerisapi.com/observations/summary/closest?p=10.6918,-61.2225&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 73 location nan, Cambodia
# https://api.aerisapi.com/observations/summary/closest?p=11.55,104.9167&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 74 location nan, Guinea-Bissau
# https://api.aerisapi.com/observations/summary/closest?p=11.8037,-15.1804&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 75 location nan, Djibouti
# https://api.aerisapi.com/observations/summary/closest?p=11.8251,42.5903&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 76 location nan, Grenada
# https://api.aerisapi.com/observations/summary/closest?p=12.1165,-61.678999999999995&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 77 location Curacao, Netherlands
# https://api.aerisapi.com/observations/summary/closest?p=12.1696,-68.99&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 78 location Bonaire, Sint Eustatius and Saba, Netherlands
# https://api.aerisapi.com/observations/summary/closest?p=12.1784,-68.2385&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 79 location nan, Burkina Faso
# https://api.aerisapi.com/observations/summary/closest?p=12.2383,-1.5616&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 80 location Aruba, Netherlands
# https://api.aerisapi.com/observations/summary/closest?p=12.5186,-70.0358&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 81 location nan, Sudan
# https://api.aerisapi.com/observations/summary/closest?p=12.8628,30.2176&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 82 location nan, Nicaragua
# https://api.aerisapi.com/observations/summary/closest?p=12.8654,-85.2072&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 83 location nan, Saint Vincent and the Grenadines
# https://api.aerisapi.com/observations/summary/closest?p=12.9843,-61.2872&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 84 location nan, Philippines
# https://api.aerisapi.com/observations/summary/closest?p=13.0,122.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 85 location nan, Barbados
# https://api.aerisapi.com/observations/summary/closest?p=13.1939,-59.5432&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 86 location nan, Gambia
# https://api.aerisapi.com/observations/summary/closest?p=13.4432,-15.3101&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 87 location Guam, US
# https://api.aerisapi.com/observations/summary/closest?p=13.4443,144.7937&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 88 location nan, El Salvador
# https://api.aerisapi.com/observations/summary/closest?p=13.7942,-88.8965&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 89 location nan, Saint Lucia
# https://api.aerisapi.com/observations/summary/closest?p=13.9094,-60.9789&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 90 location nan, Senegal
# https://api.aerisapi.com/observations/summary/closest?p=14.4974,-14.4524&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 91 location Martinique, France
# https://api.aerisapi.com/observations/summary/closest?p=14.6415,-61.0242&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 92 location nan, Thailand
# https://api.aerisapi.com/observations/summary/closest?p=15.0,101.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 93 location Northern Mariana Islands, US
# https://api.aerisapi.com/observations/summary/closest?p=15.0979,145.6739&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 94 location nan, Eritrea
# https://api.aerisapi.com/observations/summary/closest?p=15.1794,39.7823&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 95 location nan, Honduras
# https://api.aerisapi.com/observations/summary/closest?p=15.2,-86.2419&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 96 location nan, Dominica
# https://api.aerisapi.com/observations/summary/closest?p=15.415,-61.371&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 97 location nan, Chad
# https://api.aerisapi.com/observations/summary/closest?p=15.4542,18.7322&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 98 location nan, Guatemala
# https://api.aerisapi.com/observations/summary/closest?p=15.7835,-90.2308&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 99 location nan, Vietnam
# https://api.aerisapi.com/observations/summary/closest?p=16.0,108.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 100 location Guadeloupe, France
# https://api.aerisapi.com/observations/summary/closest?p=16.25,-61.5833&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 101 location nan, Cabo Verde
# https://api.aerisapi.com/observations/summary/closest?p=16.5388,-23.0418&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 102 location Montserrat, United Kingdom
# https://api.aerisapi.com/observations/summary/closest?p=16.7425,-62.1874&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 103 location nan, Antigua and Barbuda
# https://api.aerisapi.com/observations/summary/closest?p=17.0608,-61.7964&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 104 location nan, Saint Kitts and Nevis
# https://api.aerisapi.com/observations/summary/closest?p=17.357822,-62.782998&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 105 location nan, Mali
# https://api.aerisapi.com/observations/summary/closest?p=17.570692,-3.9961660000000006&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 106 location nan, Niger
# https://api.aerisapi.com/observations/summary/closest?p=17.6078,8.0817&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 107 location Saint Barthelemy, France
# https://api.aerisapi.com/observations/summary/closest?p=17.9,-62.8333&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 108 location Sint Maarten, Netherlands
# https://api.aerisapi.com/observations/summary/closest?p=18.0425,-63.0548&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 109 location St Martin, France
# https://api.aerisapi.com/observations/summary/closest?p=18.0708,-63.0501&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 110 location nan, Jamaica
# https://api.aerisapi.com/observations/summary/closest?p=18.1096,-77.2975&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 111 location Anguilla, United Kingdom
# https://api.aerisapi.com/observations/summary/closest?p=18.2206,-63.0686&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 112 location Puerto Rico, US
# https://api.aerisapi.com/observations/summary/closest?p=18.2208,-66.5901&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 113 location Virgin Islands, US
# https://api.aerisapi.com/observations/summary/closest?p=18.3358,-64.8963&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 114 location British Virgin Islands, United Kingdom
# https://api.aerisapi.com/observations/summary/closest?p=18.4207,-64.64&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 115 location nan, Dominican Republic
# https://api.aerisapi.com/observations/summary/closest?p=18.7357,-70.1627&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 116 location nan, Haiti
# https://api.aerisapi.com/observations/summary/closest?p=18.9712,-72.2852&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 117 location Hainan, China
# https://api.aerisapi.com/observations/summary/closest?p=19.1959,109.7453&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 118 location Cayman Islands, United Kingdom
# https://api.aerisapi.com/observations/summary/closest?p=19.3133,-81.2546&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 119 location Hawaii, US
# https://api.aerisapi.com/observations/summary/closest?p=19.60121157,-155.5210167&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 120 location nan, Laos
# https://api.aerisapi.com/observations/summary/closest?p=19.856270000000002,102.495496&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 121 location Hawaii, US
# https://api.aerisapi.com/observations/summary/closest?p=20.86399628,-156.56890969999998&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 122 location nan, Oman
# https://api.aerisapi.com/observations/summary/closest?p=21.0,57.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 123 location nan, India
# https://api.aerisapi.com/observations/summary/closest?p=21.0,78.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 124 location nan, Mauritania
# https://api.aerisapi.com/observations/summary/closest?p=21.0079,10.9408&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 125 location Hawaii, US
# https://api.aerisapi.com/observations/summary/closest?p=21.0943,-157.8584&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 126 location Hawaii, US
# https://api.aerisapi.com/observations/summary/closest?p=21.17882515,-156.9583592&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 127 location Hawaii, US
# https://api.aerisapi.com/observations/summary/closest?p=21.45803166,-157.97121819999998&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 128 location Turks and Caicos Islands, United Kingdom
# https://api.aerisapi.com/observations/summary/closest?p=21.694000000000003,-71.7979&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 129 location nan, Burma
# https://api.aerisapi.com/observations/summary/closest?p=21.9162,95.956&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 130 location nan, Cuba
# https://api.aerisapi.com/observations/summary/closest?p=22.0,-80.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 131 location Hawaii, US
# https://api.aerisapi.com/observations/summary/closest?p=22.03935037,-159.5966786&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 132 location Macau, China
# https://api.aerisapi.com/observations/summary/closest?p=22.1667,113.55&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 133 location Hong Kong, China
# https://api.aerisapi.com/observations/summary/closest?p=22.3,114.2&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 134 location Guangdong, China
# https://api.aerisapi.com/observations/summary/closest?p=23.3417,113.4244&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 135 location nan, Mexico
# https://api.aerisapi.com/observations/summary/closest?p=23.6345,-102.5528&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 136 location nan, Bangladesh
# https://api.aerisapi.com/observations/summary/closest?p=23.685,90.3563&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 137 location nan, Taiwan*
# https://api.aerisapi.com/observations/summary/closest?p=23.7,121.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 138 location Guangxi, China
# https://api.aerisapi.com/observations/summary/closest?p=23.8298,108.7881&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 139 location nan, Saudi Arabia
# https://api.aerisapi.com/observations/summary/closest?p=24.0,45.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 140 location nan, United Arab Emirates
# https://api.aerisapi.com/observations/summary/closest?p=24.0,54.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 141 location Yunnan, China
# https://api.aerisapi.com/observations/summary/closest?p=24.974,101.48700000000001&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 142 location nan, Bahamas
# https://api.aerisapi.com/observations/summary/closest?p=25.0343,-77.3963&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 143 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=25.20904673,-81.07812416&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 144 location nan, Qatar
# https://api.aerisapi.com/observations/summary/closest?p=25.3548,51.1839&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 145 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=25.6112362,-80.55170587&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 146 location nan, Egypt
# https://api.aerisapi.com/observations/summary/closest?p=26.0,30.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 147 location nan, Bahrain
# https://api.aerisapi.com/observations/summary/closest?p=26.0275,50.55&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 148 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=26.07,-86.9824&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 149 location Fujian, China
# https://api.aerisapi.com/observations/summary/closest?p=26.0789,117.9874&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 150 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=26.11091986,-81.34687065&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 151 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=26.14524221,-97.48140372&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 152 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=26.15184651,-80.48725556&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 153 location nan, Libya
# https://api.aerisapi.com/observations/summary/closest?p=26.3351,17.228331&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 154 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=26.39418217,-98.18299696&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 155 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=26.47411727,-97.61535848&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 156 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=26.55386945,-81.16469006&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 157 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=26.56150059,-98.73892358&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 158 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=26.58410348,-81.88399313&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 159 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=26.64676272,-80.46536002&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 160 location Guizhou, China
# https://api.aerisapi.com/observations/summary/closest?p=26.8154,106.8748&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 161 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=26.90131002,-81.92949121&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 162 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=26.92601662,-97.66413984&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 163 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=26.95635849,-81.18996211&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 164 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=27.00156391,-99.16987152&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 165 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=27.03103197,-98.21808402&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 166 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=27.04453923,-98.69681870000001&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 167 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=27.0772071,-80.43109784&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 168 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=27.18546175,-82.33174248&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 169 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=27.18677893,-81.80941373&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 170 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=27.34254618,-81.34071957&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 171 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=27.37763908,-80.47106649&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 172 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=27.386336199999995,-80.88944347&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 173 location Texas, US
# https://api.aerisapi.com/observations/summary/closest?p=27.42435506,-97.69894948&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 174 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=27.47196942,-82.31831044&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 175 location Florida, US
# https://api.aerisapi.com/observations/summary/closest?p=27.49293939,-81.80956574&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 176 location nan, Bhutan
# https://api.aerisapi.com/observations/summary/closest?p=27.5142,90.4336&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 177 location Hunan, China
# https://api.aerisapi.com/observations/summary/closest?p=27.6104,111.7088&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 178 location Jiangxi, China
# https://api.aerisapi.com/observations/summary/closest?p=27.614,115.7221&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 179 location Texas, US
# ...
# https://api.aerisapi.com/observations/summary/closest?p=49.8153,6.1296&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3402 location nan, Czechia
# https://api.aerisapi.com/observations/summary/closest?p=49.8175,15.472999999999999&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3403 location nan, Belgium
# https://api.aerisapi.com/observations/summary/closest?p=50.8333,4.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3404 location nan, Germany
# https://api.aerisapi.com/observations/summary/closest?p=51.0,9.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3405 location Ontario, Canada
# https://api.aerisapi.com/observations/summary/closest?p=51.2538,-85.3232&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3406 location nan, Poland
# https://api.aerisapi.com/observations/summary/closest?p=51.9194,19.1451&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3407 location nan, Netherlands
# https://api.aerisapi.com/observations/summary/closest?p=52.1326,5.2913&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3408 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=52.72541116,-110.4086433&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3409 location Saskatchewan, Canada
# https://api.aerisapi.com/observations/summary/closest?p=52.9399,-106.4509&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3410 location Quebec, Canada
# https://api.aerisapi.com/observations/summary/closest?p=52.9399,-73.5491&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3411 location Newfoundland and Labrador, Canada
# https://api.aerisapi.com/observations/summary/closest?p=53.1355,-57.6604&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3412 location nan, Ireland
# https://api.aerisapi.com/observations/summary/closest?p=53.1424,-7.6921&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3413 location nan, Belarus
# https://api.aerisapi.com/observations/summary/closest?p=53.7098,27.9534&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3414 location Manitoba, Canada
# https://api.aerisapi.com/observations/summary/closest?p=53.7609,-98.8139&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3415 location Alberta, Canada
# https://api.aerisapi.com/observations/summary/closest?p=53.9333,-116.5765&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3416 location Isle of Man, United Kingdom
# https://api.aerisapi.com/observations/summary/closest?p=54.2361,-4.5481&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3417 location nan, Lithuania
# https://api.aerisapi.com/observations/summary/closest?p=55.1694,23.8813&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3418 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=55.32222414,-161.9722021&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3419 location nan, United Kingdom
# https://api.aerisapi.com/observations/summary/closest?p=55.3781,-3.4360000000000004&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3420 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=55.57445008,-130.975561&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3421 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=55.76261984,-133.0511621&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3422 location nan, Denmark
# https://api.aerisapi.com/observations/summary/closest?p=56.2639,9.5018&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3423 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=56.3202004,-132.05837309999998&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3424 location nan, Latvia
# https://api.aerisapi.com/observations/summary/closest?p=56.8796,24.6032&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3425 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=57.13978948,-132.9540995&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3426 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=57.24124555,-135.3206587&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3427 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=57.65529415,-153.7493579&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3428 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=58.29307365,-135.64244240000002&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3429 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=58.45031811,-134.200436&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3430 location nan, Estonia
# https://api.aerisapi.com/observations/summary/closest?p=58.5953,25.0136&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3431 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=58.62403337,-156.21405890000003&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3432 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=58.74513976,-156.701064&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3433 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=59.09893571,-135.4679843&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3434 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=59.56149996,-135.33377480000001&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3435 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=59.79603738,-158.23819419999998&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3436 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=59.890980799999994,-140.36014509999998&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3437 location nan, Russia
# https://api.aerisapi.com/observations/summary/closest?p=60.0,90.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3438 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=60.24429722,-151.53888840000002&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3439 location nan, Norway
# https://api.aerisapi.com/observations/summary/closest?p=60.472,8.4689&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3440 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=60.90980451,-159.8561831&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3441 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=61.14998174,-149.14269860000002&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3442 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=61.3707,-152.4044&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3443 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=61.47502768,-144.7126799&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3444 location Faroe Islands, Denmark
# https://api.aerisapi.com/observations/summary/closest?p=61.8926,-6.9118&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3445 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=62.15429159999999,-163.39678830000003&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3446 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=62.31305045,-149.5741743&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3447 location nan, Sweden
# https://api.aerisapi.com/observations/summary/closest?p=63.0,16.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3448 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=63.67264044,-150.0076108&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3449 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=63.87692095,-143.2127643&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3450 location nan, Finland
# https://api.aerisapi.com/observations/summary/closest?p=64.0,26.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3451 location Yukon, Canada
# https://api.aerisapi.com/observations/summary/closest?p=64.2823,-135.0&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3452 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=64.80726247,-146.5692662&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3453 location Northwest Territories, Canada
# https://api.aerisapi.com/observations/summary/closest?p=64.8255,-124.8457&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3454 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=64.90320724,-164.0353804&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3455 location nan, Iceland
# https://api.aerisapi.com/observations/summary/closest?p=64.9631,-19.0208&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3456 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=65.50815459,-151.39073869999999&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3457 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=67.04919196,-159.7503946&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3458 location Alaska, US
# https://api.aerisapi.com/observations/summary/closest?p=69.31479216,-153.4836093&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# collecting for 3459 location Greenland, Denmark
# https://api.aerisapi.com/observations/summary/closest?p=71.7069,-42.6043&from=03/01/2020&to=04/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM

# %% [markdown]
# ###### HANDLE NaN AND SAVE DATA

# %%
data
# Out:
#         Case_Type    Cases  Difference       Date        Country_Region  \
# 0          Deaths      0.0         0.0  2/27/2020               Bahamas
# 1       Confirmed     16.0         0.0  2/16/2020               Germany
# 2          Deaths      0.0         0.0  1/31/2020                Canada
# 3          Deaths      0.0         0.0   3/4/2020             Australia
# 4       Confirmed      0.0         0.0  1/25/2020              Suriname
# 5          Deaths      0.0         0.0   2/7/2020               Estonia
# 6       Confirmed      0.0         0.0  2/24/2020              Slovakia
# 7          Deaths      0.0         0.0  3/23/2020           Timor-Leste
# 8          Deaths      6.0         0.0  2/24/2020                 China
# 9       Confirmed      0.0         0.0   2/7/2020       North Macedonia
# 10      Confirmed      0.0         0.0  1/30/2020               Estonia
# 11         Deaths      0.0         0.0   2/8/2020                Israel
# 12         Deaths      0.0         0.0  2/23/2020           Netherlands
# 13         Deaths      0.0         0.0  2/29/2020               Namibia
# 14         Deaths      0.0         0.0  3/11/2020                France
# 15      Confirmed  19665.0      2987.0   2/5/2020                 China
# 16      Confirmed   1177.0        18.0  2/11/2020                 China
# 17      Confirmed      0.0         0.0  1/29/2020            Mozambique
# 18         Deaths      0.0         0.0  2/16/2020  United Arab Emirates
# 19      Confirmed    387.0         0.0  3/25/2020             Argentina
# 20         Deaths      0.0         0.0  2/15/2020                 China
# 21      Confirmed      2.0         0.0  3/14/2020              Honduras
# 22         Deaths      0.0         0.0  3/18/2020                 Malta
# 23      Confirmed      0.0         0.0  2/21/2020                 Gabon
# 24         Deaths      0.0         0.0  3/14/2020        United Kingdom
# 25         Deaths      6.0         0.0  3/14/2020                 China
# 26      Confirmed     67.0        15.0  3/17/2020              Bulgaria
# 27         Deaths      0.0         0.0  3/14/2020                Canada
# 28         Deaths      0.0         0.0   3/5/2020                France
# 29         Deaths      0.0         0.0  2/15/2020             Singapore
# ...           ...      ...         ...        ...                   ...
# 113480     Deaths      0.0         NaN  3/23/2020                    US
# 113481  Confirmed      3.0         NaN  3/23/2020                    US
# 113482     Deaths      0.0         NaN  3/23/2020                    US
# 113483     Deaths      0.0         NaN  3/23/2020                    US
# 113484     Deaths      0.0         NaN  3/23/2020                    US
# 113485  Confirmed      0.0         NaN  3/23/2020                    US
# 113486  Confirmed      0.0         NaN  3/23/2020                    US
# 113487     Deaths      0.0         NaN  3/23/2020                    US
# 113488     Deaths      0.0         NaN  3/23/2020                    US
# 113489     Deaths      0.0         NaN  3/23/2020                    US
# 113490     Deaths      0.0         NaN  3/23/2020                    US
# 113491  Confirmed      6.0         NaN  3/23/2020                    US
# 113492  Confirmed      1.0         NaN  3/23/2020                    US
# 113493  Confirmed      1.0         NaN  3/23/2020                    US
# 113494  Confirmed      1.0         NaN  3/23/2020                    US
# 113495  Confirmed      6.0         NaN  3/23/2020                    US
# 113496     Deaths      0.0         NaN  3/23/2020                    US
# 113497  Confirmed      1.0         NaN  3/23/2020                    US
# 113498  Confirmed      1.0         NaN  3/23/2020                    US
# 113499  Confirmed     41.0         NaN  3/23/2020                    US
# 113500     Deaths      0.0         NaN  3/23/2020                    US
# 113501  Confirmed      0.0         NaN  3/23/2020                    US
# 113502     Deaths      0.0         NaN  3/23/2020                    US
# 113503     Deaths      2.0         NaN  3/23/2020                    US
# 113504     Deaths      0.0         NaN  3/23/2020                    US
# 113505     Deaths      1.0         NaN  3/23/2020                    US
# 113506     Deaths      0.0         NaN  3/23/2020                    US
# 113507  Confirmed      6.0         NaN  3/23/2020                    US
# 113508  Confirmed      0.0         NaN  3/23/2020                    US
# 113509     Deaths      0.0         NaN  3/23/2020                    US
#
#               Province_State         Admin2                     Combined_Key  \
# 0                        NaN            NaN                              NaN
# 1                        NaN            NaN                              NaN
# 2                    Alberta            NaN                              NaN
# 3                 Queensland            NaN                              NaN
# 4                        NaN            NaN                              NaN
# 5                        NaN            NaN                              NaN
# 6                        NaN            NaN                              NaN
# 7                        NaN            NaN                              NaN
# 8                      Hebei            NaN                              NaN
# 9                        NaN            NaN                              NaN
# 10                       NaN            NaN                              NaN
# 11                       NaN            NaN                              NaN
# 12              Sint Maarten            NaN                              NaN
# 13                       NaN            NaN                              NaN
# 14                 St Martin            NaN                              NaN
# 15                     Hubei            NaN                              NaN
# 16                 Guangdong            NaN                              NaN
# 17                       NaN            NaN                              NaN
# 18                       NaN            NaN                              NaN
# 19                       NaN            NaN                              NaN
# 20                    Yunnan            NaN                              NaN
# 21                       NaN            NaN                              NaN
# 22                       NaN            NaN                              NaN
# 23                       NaN            NaN                              NaN
# 24                   Bermuda            NaN                              NaN
# 25                    Hainan            NaN                              NaN
# 26                       NaN            NaN                              NaN
# 27      Prince Edward Island            NaN                              NaN
# 28          French Polynesia            NaN                              NaN
# 29                       NaN            NaN                              NaN
# ...                      ...            ...                              ...
# 113480          South Dakota         Potter         Potter, South Dakota, US
# 113481             Louisiana     St. Landry        St. Landry, Louisiana, US
# 113482                  Iowa        Fayette                Fayette, Iowa, US
# 113483               Georgia         Echols              Echols, Georgia, US
# 113484               Georgia         Jasper              Jasper, Georgia, US
# 113485             Minnesota       Red Lake          Red Lake, Minnesota, US
# 113486          South Dakota           Todd           Todd, South Dakota, US
# 113487             Louisiana          Grant             Grant, Louisiana, US
# 113488          South Dakota  Oglala Lakota  Oglala Lakota, South Dakota, US
# 113489        North Carolina         Wilson       Wilson, North Carolina, US
# 113490                  Iowa          Wayne                  Wayne, Iowa, US
# 113491                  Iowa           Linn                   Linn, Iowa, US
# 113492          Pennsylvania        Fayette        Fayette, Pennsylvania, US
# 113493        North Carolina          Wayne        Wayne, North Carolina, US
# 113494                 Texas         Gaines                Gaines, Texas, US
# 113495         New Hampshire        Carroll       Carroll, New Hampshire, US
# 113496          South Dakota          Moody          Moody, South Dakota, US
# 113497        North Carolina     Pasquotank   Pasquotank, North Carolina, US
# 113498              Michigan          Clare              Clare, Michigan, US
# 113499               Florida       Pinellas            Pinellas, Florida, US
# 113500              New York       Schuyler           Schuyler, New York, US
# 113501             Minnesota           Lake              Lake, Minnesota, US
# 113502             Wisconsin           Polk              Polk, Wisconsin, US
# 113503               Florida           Clay                Clay, Florida, US
# 113504                  Iowa        Kossuth                Kossuth, Iowa, US
# 113505              Maryland     Montgomery         Montgomery, Maryland, US
# 113506                Oregon      Jefferson            Jefferson, Oregon, US
# 113507         Massachusetts      Hampshire     Hampshire, Massachusetts, US
# 113508                Kansas       Marshall             Marshall, Kansas, US
# 113509              Nebraska         Garden             Garden, Nebraska, US
#
#            FIPS        Lat      ...       avg_wind avg_precip avg_m_tmp  \
# 0           NaN  25.034300      ...            NaN        NaN       NaN
# 1           NaN  51.000000      ...            NaN        NaN       NaN
# 2           NaN  53.933300      ...            NaN        NaN       NaN
# 3           NaN -28.016700      ...            NaN        NaN       NaN
# 4           NaN   3.919300      ...            NaN        NaN       NaN
# 5           NaN  58.595300      ...            NaN        NaN       NaN
# 6           NaN  48.669000      ...            NaN        NaN       NaN
# 7           NaN  -8.874217      ...            NaN        NaN       NaN
# 8           NaN  39.549000      ...            NaN        NaN       NaN
# 9           NaN  41.608600      ...            NaN        NaN       NaN
# 10          NaN  58.595300      ...            NaN        NaN       NaN
# 11          NaN  31.000000      ...            NaN        NaN       NaN
# 12          NaN  18.042500      ...            NaN        NaN       NaN
# 13          NaN -22.957600      ...            NaN        NaN       NaN
# 14          NaN  18.070800      ...            NaN        NaN       NaN
# 15          NaN  30.975600      ...            NaN        NaN       NaN
# 16          NaN  23.341700      ...            NaN        NaN       NaN
# 17          NaN -18.665695      ...            NaN        NaN       NaN
# 18          NaN  24.000000      ...            NaN        NaN       NaN
# 19          NaN -38.416100      ...            NaN        NaN       NaN
# 20          NaN  24.974000      ...            NaN        NaN       NaN
# 21          NaN  15.200000      ...            NaN        NaN       NaN
# 22          NaN  35.937500      ...            NaN        NaN       NaN
# 23          NaN  -0.803700      ...            NaN        NaN       NaN
# 24          NaN  32.307800      ...            NaN        NaN       NaN
# 25          NaN  19.195900      ...            NaN        NaN       NaN
# 26          NaN  42.733900      ...            NaN        NaN       NaN
# 27          NaN  46.510700      ...            NaN        NaN       NaN
# 28          NaN -17.679700      ...            NaN        NaN       NaN
# 29          NaN   1.283300      ...            NaN        NaN       NaN
# ...         ...        ...      ...            ...        ...       ...
# 113480  46107.0  45.065831      ...            NaN        NaN       NaN
# 113481  22097.0  30.597243      ...            NaN        NaN       NaN
# 113482  19065.0  42.862718      ...            NaN        NaN       NaN
# 113483  13101.0  30.711011      ...            NaN        NaN       NaN
# 113484  13159.0  33.315355      ...            NaN        NaN       NaN
# 113485  27125.0  47.871975      ...            NaN        NaN       NaN
# 113486  46121.0  43.193386      ...            NaN        NaN       NaN
# 113487  22043.0  31.598825      ...            NaN        NaN       NaN
# 113488  46102.0  43.337492      ...            NaN        NaN       NaN
# 113489  37195.0  35.706255      ...            NaN        NaN       NaN
# 113490  19185.0  40.739690      ...            NaN        NaN       NaN
# 113491  19113.0  42.079231      ...            NaN        NaN       NaN
# 113492  42051.0  39.920410      ...            NaN        NaN       NaN
# 113493  37191.0  35.364381      ...            NaN        NaN       NaN
# 113494  48165.0  32.740553      ...            NaN        NaN       NaN
# 113495  33003.0  43.874986      ...            NaN        NaN       NaN
# 113496  46101.0  44.022662      ...            NaN        NaN       NaN
# 113497  37139.0  36.267238      ...            NaN        NaN       NaN
# 113498  26035.0  43.987942      ...            NaN        NaN       NaN
# 113499  12103.0  27.931303      ...            NaN        NaN       NaN
# 113500  36097.0  42.391840      ...            NaN        NaN       NaN
# 113501  27075.0  47.642708      ...            NaN        NaN       NaN
# 113502  55095.0  45.461303      ...            NaN        NaN       NaN
# 113503  12019.0  29.983191      ...            NaN        NaN       NaN
# 113504  19109.0  43.204055      ...            NaN        NaN       NaN
# 113505  24031.0  39.136763      ...            NaN        NaN       NaN
# 113506  41031.0  44.628068      ...            NaN        NaN       NaN
# 113507  25015.0  42.339980      ...            NaN        NaN       NaN
# 113508  20117.0  39.783597      ...            NaN        NaN       NaN
# 113509  31069.0  41.617031      ...            NaN        NaN       NaN
#
#         avg_m_RH  avg_m_wind  avg_m_precip  avg_d_tmp  avg_d_RH  avg_d_wind  \
# 0            NaN         NaN           NaN        NaN       NaN         NaN
# 1            NaN         NaN           NaN        NaN       NaN         NaN
# 2            NaN         NaN           NaN        NaN       NaN         NaN
# 3            NaN         NaN           NaN        NaN       NaN         NaN
# 4            NaN         NaN           NaN       25.0      88.0         8.7
# 5            NaN         NaN           NaN        NaN       NaN         NaN
# 6            NaN         NaN           NaN        NaN       NaN         NaN
# 7            NaN         NaN           NaN        NaN       NaN         NaN
# 8            NaN         NaN           NaN        NaN       NaN         NaN
# 9            NaN         NaN           NaN        NaN       NaN         NaN
# 10           NaN         NaN           NaN        NaN       NaN         NaN
# 11           NaN         NaN           NaN        NaN       NaN         NaN
# 12           NaN         NaN           NaN        NaN       NaN         NaN
# 13           NaN         NaN           NaN        NaN       NaN         NaN
# 14           NaN         NaN           NaN        NaN       NaN         NaN
# 15           NaN         NaN           NaN        NaN       NaN         NaN
# 16           NaN         NaN           NaN        NaN       NaN         NaN
# 17           NaN         NaN           NaN       28.9      70.0        15.0
# 18           NaN         NaN           NaN        NaN       NaN         NaN
# 19           NaN         NaN           NaN        NaN       NaN         NaN
# 20           NaN         NaN           NaN        NaN       NaN         NaN
# 21           NaN         NaN           NaN        NaN       NaN         NaN
# 22           NaN         NaN           NaN        NaN       NaN         NaN
# 23           NaN         NaN           NaN        NaN       NaN         NaN
# 24           NaN         NaN           NaN        NaN       NaN         NaN
# 25           NaN         NaN           NaN        NaN       NaN         NaN
# 26           NaN         NaN           NaN        NaN       NaN         NaN
# 27           NaN         NaN           NaN        NaN       NaN         NaN
# 28           NaN         NaN           NaN        NaN       NaN         NaN
# 29           NaN         NaN           NaN        NaN       NaN         NaN
# ...          ...         ...           ...        ...       ...         ...
# 113480       NaN         NaN           NaN        NaN       NaN         NaN
# 113481       NaN         NaN           NaN        NaN       NaN         NaN
# 113482       NaN         NaN           NaN        NaN       NaN         NaN
# 113483       NaN         NaN           NaN        NaN       NaN         NaN
# 113484       NaN         NaN           NaN        NaN       NaN         NaN
# 113485       NaN         NaN           NaN        NaN       NaN         NaN
# 113486       NaN         NaN           NaN        NaN       NaN         NaN
# 113487       NaN         NaN           NaN        NaN       NaN         NaN
# 113488       NaN         NaN           NaN        NaN       NaN         NaN
# 113489       NaN         NaN           NaN        NaN       NaN         NaN
# 113490       NaN         NaN           NaN        NaN       NaN         NaN
# 113491       NaN         NaN           NaN        NaN       NaN         NaN
# 113492       NaN         NaN           NaN        NaN       NaN         NaN
# 113493       NaN         NaN           NaN        NaN       NaN         NaN
# 113494       NaN         NaN           NaN        NaN       NaN         NaN
# 113495       NaN         NaN           NaN        NaN       NaN         NaN
# 113496       NaN         NaN           NaN        NaN       NaN         NaN
# 113497       NaN         NaN           NaN        NaN       NaN         NaN
# 113498       NaN         NaN           NaN        NaN       NaN         NaN
# 113499       NaN         NaN           NaN        NaN       NaN         NaN
# 113500       NaN         NaN           NaN        NaN       NaN         NaN
# 113501       NaN         NaN           NaN        NaN       NaN         NaN
# 113502       NaN         NaN           NaN        NaN       NaN         NaN
# 113503       NaN         NaN           NaN        NaN       NaN         NaN
# 113504       NaN         NaN           NaN        NaN       NaN         NaN
# 113505       NaN         NaN           NaN        NaN       NaN         NaN
# 113506       NaN         NaN           NaN        NaN       NaN         NaN
# 113507       NaN         NaN           NaN        NaN       NaN         NaN
# 113508       NaN         NaN           NaN        NaN       NaN         NaN
# 113509       NaN         NaN           NaN        NaN       NaN         NaN
#
#         avg_d_precip
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                0.0
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               0.0
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ...              ...
# 113480           NaN
# 113481           NaN
# 113482           NaN
# 113483           NaN
# 113484           NaN
# 113485           NaN
# 113486           NaN
# 113487           NaN
# 113488           NaN
# 113489           NaN
# 113490           NaN
# 113491           NaN
# 113492           NaN
# 113493           NaN
# 113494           NaN
# 113495           NaN
# 113496           NaN
# 113497           NaN
# 113498           NaN
# 113499           NaN
# 113500           NaN
# 113501           NaN
# 113502           NaN
# 113503           NaN
# 113504           NaN
# 113505           NaN
# 113506           NaN
# 113507           NaN
# 113508           NaN
# 113509           NaN
#
# [113510 rows x 25 columns]

# %%
backup = data.copy()
# data[['Province_State']] = data[['Province_State']].fillna(0)
# data = data.drop('avg_sun', axis=1)
# data = data.dropna()

# %%
##############################################
# COMPUTE AVG PARAMETERS FOR CONFIRMED CASES #
##############################################

conf_data = data[data['Case_Type'] == 'Confirmed']
death_data = data[data['Case_Type'] == 'Deaths']
for coord in coords:
    lat = coord[0]
    long = coord[1]
    indices = conf_data.loc[conf_data['Lat'] == lat].loc[conf_data['Long'] == long].index.tolist()
    avg_tmp = conf_data.loc[conf_data['Lat'] == lat]\
                       .loc[conf_data['Long'] == long]['avg_tmp'].mean()
    
    avg_rh = conf_data.loc[conf_data['Lat'] == lat]\
                   .loc[conf_data['Long'] == long]['avg_RH'].mean()
    
    avg_wind = conf_data.loc[conf_data['Lat'] == lat]\
                   .loc[conf_data['Long'] == long]['avg_wind'].mean()
    
    avg_precip = conf_data.loc[conf_data['Lat'] == lat]\
                   .loc[conf_data['Long'] == long]['avg_precip'].mean()                             
    
    for index in indices:
        conf_data.at[index, 'avg_m_tmp'] = avg_tmp
        conf_data.at[index, 'avg_m_RH'] = avg_rh
        conf_data.at[index, 'avg_m_wind'] = avg_wind
        conf_data.at[index, 'avg_m_precip'] = avg_precip

# %% [markdown]
# ###### COMPUTE AVG PARAMETERS FOR DEATHS CASES

# %%
for coord in coords:
    lat = coord[0]
    long = coord[1]
    indices = death_data.loc[data['Lat'] == lat].loc[death_data['Long'] == long].index.tolist()
    avg_tmp = death_data.loc[death_data['Lat'] == lat]\
                       .loc[death_data['Long'] == long]['avg_tmp'].mean()
    
    avg_rh = death_data.loc[death_data['Lat'] == lat]\
                   .loc[death_data['Long'] == long]['avg_RH'].mean()
    
    avg_wind = death_data.loc[death_data['Lat'] == lat]\
                   .loc[death_data['Long'] == long]['avg_wind'].mean()
    
    avg_precip = death_data.loc[death_data['Lat'] == lat]\
                   .loc[death_data['Long'] == long]['avg_precip'].mean()                             
    
    for index in indices:
        death_data.at[index, 'avg_m_tmp'] = avg_tmp
        death_data.at[index, 'avg_m_RH'] = avg_rh
        death_data.at[index, 'avg_m_wind'] = avg_wind
        death_data.at[index, 'avg_m_precip'] = avg_precip

# %%
#########################
# This was to fix a bug #
#########################

# conf_data = pd.read_csv('../augmented_datasets/tableau_conf_data.csv')
# death_data = pd.read_csv('../augmented_datasets/tableau_death_data.csv')
# conf_data = conf_data.drop('Unnamed: 0', axis=1)
# death_data = death_data.drop('Unnamed: 0', axis=1)
# conf_data['Date'] = conf_data['Date'].apply(lambda x: x.lstrip('0'))
# death_data['Date'] = death_data['Date'].apply(lambda x: x.lstrip('0'))

##############################
# This is for multi-indexing #
##############################

# conf_data['Date'] = pd.DatetimeIndex(conf_data['Date'])
# conf_data.set_index(conf_data['Date'], append=True, inplace=True, drop=True)
# conf_data.loc[2, '2020']

# %% [markdown]
# ###### COMPUTE GROWTH-FACTOR AND MAX CASES, MAX DATE FOR CONFIRMED CASES

# %%
conf_data['max_date'] = ''
conf_data['growth_factor'] = np.nan
conf_data['max_cases'] = np.nan

for coord in coords:
    lat = coord[0]
    long = coord[1]
    max_cases = conf_data.loc[conf_data['Lat'] == lat]\
                         .loc[conf_data['Long'] == long]['Cases'].max()
    if not pd.notna(max_cases):
        continue
    max_date = conf_data.loc[conf_data['Lat'] == lat]\
                        .loc[conf_data['Long'] == long][conf_data['Cases'] == max_cases]['Date']
    
    max_date_parsed = datetime.strptime(max_date.values[0], '%m/%d/%Y')
    four_days = max_date_parsed - timedelta(days = 4)
    four_days = four_days.strftime('%-m/%d/%Y')
    
    try:
        four_days_cases = conf_data.loc[conf_data['Lat'] == lat]\
                         .loc[conf_data['Long'] == long]\
                         .loc[conf_data['Date'] == four_days]['Cases'].values[0]
        if max_cases > four_days_cases and four_days_cases != 0:
            rate = max_cases / four_days_cases 
            growth_factor = rate**0.25
        else:
            growth_factor = 1
    
    except IndexError:
        growth_factor = 1
        
    indices = conf_data.loc[conf_data['Lat'] == lat]\
                        .loc[conf_data['Long'] == long].index.tolist()
    for index in indices:
        conf_data.at[index, 'max_date'] = max_date.values[0] 
        conf_data.at[index, 'growth_factor'] = growth_factor
        conf_data.at[index, 'max_cases'] = max_cases
# Out:
# /Users/nirweingarten/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app

# %%
death_data.loc[death_data['Lat'] == lat]\
                         .loc[death_data['Long'] == long]\
                         .loc[death_data['Date'] == four_days]['Cases']
# Out:
# Series([], Name: Cases, dtype: int64)

# %% [markdown]
# ###### COMPUTE GROWTH-FACTOR AND MAX CASES, MAX DATE FOR DEATH CASES

# %%
death_data['max_date'] = ''
death_data['growth_factor'] = np.nan
death_data['max_cases'] = np.nan

for coord in coords:
    lat = coord[0]
    long = coord[1]
    max_cases = death_data.loc[death_data['Lat'] == lat]\
                         .loc[death_data['Long'] == long]['Cases'].max()
    if not pd.notna(max_cases):
        continue
    max_date = death_data.loc[death_data['Lat'] == lat]\
                        .loc[death_data['Long'] == long][death_data['Cases'] == max_cases]['Date']
    
    max_date_parsed = datetime.strptime(max_date.values[0], '%m/%d/%Y')
    four_days = max_date_parsed - timedelta(days = 4)
    four_days = four_days.strftime('%-m/%d/%Y')
    
    try:
        four_days_cases = death_data.loc[death_data['Lat'] == lat]\
                         .loc[death_data['Long'] == long]\
                         .loc[death_data['Date'] == four_days]['Cases'].values[0]
        if max_cases > four_days_cases and four_days_cases != 0:
            rate = max_cases / four_days_cases 
            growth_factor = rate**0.25
        else:
            growth_factor = 1
    
    except IndexError:
        growth_factor = 1
    
    indices = death_data.loc[death_data['Lat'] == lat]\
                        .loc[death_data['Long'] == long].index.tolist()
    for index in indices:
        death_data.at[index, 'max_date'] = max_date.values[0] 
        death_data.at[index, 'growth_factor'] = growth_factor
        death_data.at[index, 'max_cases'] = max_cases
# Out:
# /Users/nirweingarten/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# 24

# %%
"""
Somehow there are 580 entries in death_cont that are not in coords
resulting in NaN values for growth factor, we will remove them for the meanwhile
"""
death_data = death_data.dropna()
# Out:
# '\nSomehow there are 580 entries in death_cont that are not in coords\nresulting in NaN values for growth factor, we will remove them for the meanwhile\n'

# %% [markdown]
# ###### Add 5% interval and averages

# %%
conf_data['5% date'] = ''
conf_data['avg_interval_tmp'] = np.nan
conf_data['avg_interval_RH'] = np.nan

# %%
for coord in coords:
    lat = coord[0]
    long = coord[1]
    max_cases = int(conf_data.loc[conf_data['Lat'] == lat]\
                         .loc[conf_data['Long'] == long]['max_cases'].values[0])
    if not pd.notna(max_cases):
        continue
    five_prcnt = int(0.05 * max_cases)
    
    five_prcnt_date = conf_data.loc[conf_data['Lat'] == lat]\
                            .loc[conf_data['Long'] == long][conf_data['Cases'] >= five_prcnt]['Date'].min()
    
    max_date = conf_data.loc[conf_data['Lat'] == lat]\
                         .loc[conf_data['Long'] == long]['max_date'].values[0]
    
    interval = conf_data.loc[conf_data['Lat'] == lat]\
                            .loc[conf_data['Long'] == long][(conf_data['Date'] >= five_prcnt_date)\
                                                            & (conf_data['Date'] <= max_date)]
    indices = conf_data.loc[conf_data['Lat'] == lat]\
                        .loc[conf_data['Long'] == long].index.tolist()
    for index in indices:
        conf_data.at[index, '5% date'] = five_prcnt_date 
        conf_data.at[index, 'avg_interval_tmp'] = interval['avg_tmp'].mean()
        conf_data.at[index, 'avg_interval_RH'] = interval['avg_RH'].mean()

# %% [markdown]
# ###### Sanity checks
# Manual heuristic comparison of selected samples from the dataset
# We compared 5 randomly selected data entries as follows:
# 1. lat and lan on google map
# 2. Daily information with Aeris API
# 3. Daily information with a third party climate source - https://www.worldweatheronline.com/
# 4. monthly information with a third party data source (This will only be an approximation) https://www.timeanddate.com/weather/israel/tel-aviv/climate
#
# Note that coordinates are in decimal representation
#
# ###### Entries for sanity check:
#               Lat	Long	avg_tmp	avg_RH	avg_wind	avg_precip	avg_m_tmp	avg_m_RH	avg_m_wind avg_m_precip
# - Israel, 03/01/20, 31	35	15.3	68	23	0	14.99310345	74.5862069	13.11034483	0
#     * Google maps
#         - Checks good at Dimona
#     * Check API
#         - Checks good at Ben Gurion Air Port
#     * Third party daily
#         - no Ben gurion only Tel aviv
#         - Everything seems good except percipitation
#     * Third party monthly
#          - Everything seems good except percipitation
# - Afghanistan, 03/21/20 33	65	18.7	41	2.4	0	13.71315789	47.07894737	5.684210526	0.855526316
#     * Google maps
#         - On the mountains 200km south west of Kabul (middle of country)
#     * Check API
#         - Checks good at kandahar intl ar
#     * Third party daily
#          - Checks good, wind seems to much
#     * Third party monthly
#          - tmp ~3c less
#          - RH ~10% more
#          - m wind 5.6 instead of 14 on third part
#          - m precip 0.85 instead of 3.8 in third party
# - Queensland Australia, 02/03/20 -28.0167	153.4	25.6	78	12.8	0	24.05	75.55263158	16.66842105	0
#     * Google maps
#         - southport, in the south eastern corner of Queensland (metropolitan, but not the capital)
#     * Check API
#         - Checks good at the same town
#     * Third party daily
#         - Checks good
#     * Third party monthly
#         - Checks good expect precipitation
# - Fiji, 03/06/20 -17.7134	178.065	26.6	90	3.2	0	26.84473684	85.47368421	5.871052632	0
#     * Google maps
#         - The the northen third of Fiji
#     * Check API
#         - Checks good for Nausori (60km south east)
#     * Third party daily
#         - Checks good exepct wind that seems week and precipitation that should be a little
#     * Third party monthly
#         - seems good exepct for precipitation
# - North Dakota, US 03/12/20 47.5289	-99.784	-0.2	73	31.5	0	-4.947368421	80.52631579	18.72368421	0
#     * Google maps
#         - In the fields around the middle of the state
#     * Check API
#          - Checks good for harvey (10km north west)
#     * Third party daily
#         -
#     * Third party monthly
#         - checks good except precipitation
#
# After comparing the data we conclude it is relaibale except for precpitation that will be hence forth ignored.

# %%
data = pd.read_csv('../augmented_datasets/tableau_conf_data.csv')
RADIUS = 350

coords = [(31, 35), (33, 65), (-28.0167, 153.4), (-17.7134, 178.065), (47.5289, -99.784)] 
dates = ['03/01/2020', '03/21/2020', '03/02/2020', '03/06/2020', '03/12/2020']

for i in range(5):
    lat = coords[i][0]
    long = coords[i][1]
    start_time = dates[i]
    end_time = dates[i]
    location = data.loc[data['Lat'] == lat]\
                    .loc[data['Long'] == long]\
                     [['Country_Region','Province_State']]
    country = location.iloc[0][0]
    province = location.iloc[0][1]
    url = 'https://api.aerisapi.com/observations/summary/closest?p={0},{1}&from={2}&to={3}&radius={4}miles&plimit=31&limit=1&'\
          'client_id={5}&client_secret={6}'.format(lat, long, start_time, end_time, RADIUS, client_id, client_secret)
    print('collecting for {0} location {1}, {2}\n{3}'.format(i, province, country, url))
    request = urllib.request.urlopen(url)
    response = request.read()
    json_ = json.loads(response)
    if json_['success']: 
        print('success')
        try:
            for day in json_['response'][0]['periods']:
                print('Location: {0}, {1}'.format(json_['response'][0]['place']['name'], json_['response'][0]['place']['city']))
                print('avg tmp: {0}'.format(day['summary']['temp']['avgC']))
                print('avg RH: {0}'.format(day['summary']['rh']['avg']))
                print('avg wind: {0}'.format(day['summary']['wind']['avgKPH']))
                print('avg precip: {0}\n'.format(day['summary']['precip']['totalMM']))
        except IndexError:
            if json_['error']:
                msg = 'No data found for {0}, {1} at {2}\n{3}\r\n'.format(country, province, date, json_['error'])
                print(msg)
        except Exception as e:
            raise e
            msg = 'Unknowen error\n{0}\r\n'.format(json_['error'])
            print(msg)
        finally:
            request.close()
# Out:
# collecting for 0 location 0, Israel
# https://api.aerisapi.com/observations/summary/closest?p=31,35&from=03/01/2020&to=03/01/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# success
# Location: ben-gurion(civ/m, ben-gurion(civ/m
# avg tmp: 15.3
# avg RH: 68
# avg wind: 23
# avg precip: 0
#
# collecting for 1 location 0, Afghanistan
# https://api.aerisapi.com/observations/summary/closest?p=33,65&from=03/21/2020&to=03/21/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# success
# Location: kandahar intl ar, kandahar intl ar
# avg tmp: 18.7
# avg RH: 41
# avg wind: 2.4
# avg precip: 0
#
# collecting for 2 location Queensland, Australia
# https://api.aerisapi.com/observations/summary/closest?p=-28.0167,153.4&from=03/02/2020&to=03/02/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# success
# Location: coolangatta aws, coolangatta aws
# avg tmp: 25.6
# avg RH: 78
# avg wind: 12.8
# avg precip: 0
#
# collecting for 3 location 0, Fiji
# https://api.aerisapi.com/observations/summary/closest?p=-17.7134,178.065&from=03/06/2020&to=03/06/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# success
# Location: nausori fiji, nausori fiji
# avg tmp: 26.6
# avg RH: 90
# avg wind: 3.2
# avg precip: 0
#
# collecting for 4 location North Dakota, US
# https://api.aerisapi.com/observations/summary/closest?p=47.5289,-99.784&from=03/12/2020&to=03/12/2020&radius=350miles&plimit=31&limit=1&client_id=tXyXXyb3Yf492X1asICz5&client_secret=WJi1enKSDGlhO8Nt4Ze00C1F6LEdMpl2O54JIwaM
# success
# Location: harvey, harvey
# avg tmp: -0.2
# avg RH: 73
# avg wind: 31.5
# avg precip: 0

# %%
######################
# SAVE COMPUTED DATA #
######################

data.to_csv('../augmented_datasets/tableau_data0403.csv')
# conf_data.to_csv('../augmented_datasets/tableau_conf_data0403.csv')
# death_data.to_csv('../augmented_datasets/tableau_death_data.csv')
