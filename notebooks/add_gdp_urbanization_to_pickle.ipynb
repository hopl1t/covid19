# %% [markdown]
# ## add gdp and urbanization data pickle file notebook

# %% [markdown]
# Adds GDP (in billion USD) and Urbanization (in population percentage) columns to given tableau and hopkins augmented data.
# Contact ShuliFinley@gmail.com for questions :)

# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# Import tableau and hopkins data

# %%
# tableau_conf_data = pd.read_csv('../augmented_datasets/tableau_conf_data.csv')
# tableau_death_data = pd.read_csv('../augmented_datasets/tableau_death_data.csv')

# hopkins_conf_data = pd.read_csv('../augmented_datasets/hopkins_conf.csv')
# hopkins_death_data = pd.read_csv('../augmented_datasets/hopkins_death.csv')

PICKLE_PATH = '../augmented_datasets/hopkins_conf_gf0304.pkl'
RESULT_PATH = '../augmented_datasets/hopkins_conf_gf0304_GDP.pkl'

hopkins_conf = pd.DataFrame()

with open(PICKLE_PATH, 'rb') as file:
    hopkins_conf = pickle.load(file)

hopkins_conf
    
# hopkins_conf_data.head()
# Out:
#                                                  Province_State  \
# coordinate           information
# (-41.4545, 145.9707) data                              Tasmania
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-40.9006, 174.886)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-38.4161, -63.6167) data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-37.8136, 144.9631) data                              Victoria
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-35.6751, -71.543)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-35.4735, 149.0124) data          Australian Capital Territory
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# ...                                                         ...
# (60.0, 90.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (60.472, 8.4689)     data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (61.8926, -6.9118)   data                         Faroe Islands
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (63.0, 16.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (64.0, 26.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (64.9631, -19.0208)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
#
#                                   Country_Region  avg_m_tmp   avg_m_RH  \
# coordinate           information
# (-41.4545, 145.9707) data              Australia  15.466667  68.818182
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (-40.9006, 174.886)  data            New Zealand  17.754545  74.772727
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (-38.4161, -63.6167) data              Argentina  22.995455  43.984848
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (-37.8136, 144.9631) data              Australia  18.592424  70.818182
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (-35.6751, -71.543)  data                  Chile  20.348485  56.090909
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (-35.4735, 149.0124) data              Australia  19.777273  62.848485
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# ...                                          ...        ...        ...
# (60.0, 90.0)         data                 Russia  -7.101515  71.909091
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (60.472, 8.4689)     data                 Norway  -0.006061  82.530303
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (61.8926, -6.9118)   data                Denmark   3.506061  81.696970
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (63.0, 16.0)         data                 Sweden  -1.584848  79.212121
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (64.0, 26.0)         data                Finland  -4.256250  83.234375
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
# (64.9631, -19.0208)  data                Iceland  -2.230159  78.571429
#                      avg_d_RH                NaN        NaN        NaN
#                      avg_d_precip            NaN        NaN        NaN
#                      avg_d_tmp               NaN        NaN        NaN
#                      avg_d_wind              NaN        NaN        NaN
#
#                                    avg_m_precip  avg_m_wind  Max_Cases  \
# coordinate           information
# (-41.4545, 145.9707) data                   0.0   18.469697       47.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (-40.9006, 174.886)  data                   0.0   26.777273      368.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (-38.4161, -63.6167) data                   0.0   10.572727      589.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (-37.8136, 144.9631) data                   0.0   17.498485      574.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (-35.6751, -71.543)  data                   0.0   12.646970     1610.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (-35.4735, 149.0124) data                   0.0   14.260606       62.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# ...                                         ...         ...        ...
# (60.0, 90.0)         data                   0.0   12.530303     1036.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (60.472, 8.4689)     data                   0.0   12.275758     3755.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (61.8926, -6.9118)   data                   0.0   23.180303      144.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (63.0, 16.0)         data                   0.0   17.298485     3069.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (64.0, 26.0)         data                   0.0   15.381250     1041.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
# (64.9631, -19.0208)  data                   0.0   16.523810      890.0
#                      avg_d_RH               NaN         NaN        NaN
#                      avg_d_precip           NaN         NaN        NaN
#                      avg_d_tmp              NaN         NaN        NaN
#                      avg_d_wind             NaN         NaN        NaN
#
#                                     first_7 last relevant date   Max_Date  \
# coordinate           information
# (-41.4545, 145.9707) data          1.333333          3/27/2020  3/26/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (-40.9006, 174.886)  data          6.750000          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (-38.4161, -63.6167) data          2.129032          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (-37.8136, 144.9631) data          2.361111          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (-35.6751, -71.543)  data          3.077419          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (-35.4735, 149.0124) data          8.750000          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# ...                                     ...                ...        ...
# (60.0, 90.0)         data          3.288136          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (60.472, 8.4689)     data          4.956098          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (61.8926, -6.9118)   data          7.888889          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (63.0, 16.0)         data          4.055901          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (64.0, 26.0)         data          4.440678          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
# (64.9631, -19.0208)  data          1.680000          3/27/2020  3/27/2020
#                      avg_d_RH           NaN
#                      avg_d_precip       NaN
#                      avg_d_tmp          NaN
#                      avg_d_wind         NaN
#
#                                      ...     3/18/2020  3/19/2020  3/20/2020  \
# coordinate           information     ...
# (-41.4545, 145.9707) data            ...          10.0       10.0       10.0
#                      avg_d_RH        ...          82.0       93.0       81.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          16.5       14.9       14.9
#                      avg_d_wind      ...          18.6        8.4       21.2
# (-40.9006, 174.886)  data            ...          20.0       28.0       39.0
#                      avg_d_RH        ...          60.0       72.0       70.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          14.1       17.0       16.4
#                      avg_d_wind      ...          21.4       35.2       25.5
# (-38.4161, -63.6167) data            ...          79.0       97.0      128.0
#                      avg_d_RH        ...          62.0       47.0       52.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          19.4       20.2       18.5
#                      avg_d_wind      ...           5.6        9.5        4.0
# (-37.8136, 144.9631) data            ...         121.0      121.0      121.0
#                      avg_d_RH        ...          44.0       44.0       64.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          23.6       25.9       18.2
#                      avg_d_wind      ...          25.6       20.3       22.6
# (-35.6751, -71.543)  data            ...         238.0      238.0      434.0
#                      avg_d_RH        ...          63.0       57.0       55.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          18.1       18.0       16.9
#                      avg_d_wind      ...          10.2       11.2        9.3
# (-35.4735, 149.0124) data            ...           3.0        4.0        6.0
#                      avg_d_RH        ...          67.0       59.0       44.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          16.2       19.8       22.0
#                      avg_d_wind      ...          11.0        8.9       23.1
# ...                                  ...           ...        ...        ...
# (60.0, 90.0)         data            ...         147.0      199.0      253.0
#                      avg_d_RH        ...          61.0       71.0       76.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          -0.2       -1.5       -0.8
#                      avg_d_wind      ...          25.4       19.6       14.8
# (60.472, 8.4689)     data            ...        1550.0     1746.0     1914.0
#                      avg_d_RH        ...          99.0       93.0       75.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          -0.6        0.6       -0.7
#                      avg_d_wind      ...           7.4        5.9        7.3
# (61.8926, -6.9118)   data            ...          58.0       72.0       80.0
#                      avg_d_RH        ...          76.0       78.0       74.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...           4.0        2.2        2.2
#                      avg_d_wind      ...          17.8       15.0       15.0
# (63.0, 16.0)         data            ...        1279.0     1439.0     1639.0
#                      avg_d_RH        ...          66.0       74.0       76.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...           1.2       -0.1       -4.1
#                      avg_d_wind      ...          12.8       29.0       17.8
# (64.0, 26.0)         data            ...         336.0      400.0      450.0
#                      avg_d_RH        ...          80.0       74.0       65.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...           0.9       -1.4       -7.5
#                      avg_d_wind      ...          15.4       11.8       11.1
# (64.9631, -19.0208)  data            ...         250.0      330.0      409.0
#                      avg_d_RH        ...          77.0       75.0       67.0
#                      avg_d_precip    ...           0.0        0.0        0.0
#                      avg_d_tmp       ...          -1.0       -6.0        2.3
#                      avg_d_wind      ...          13.4       13.6       36.3
#
#                                    3/21/2020  3/22/2020  3/23/2020  3/24/2020  \
# coordinate           information
# (-41.4545, 145.9707) data               16.0       22.0       28.0       28.0
#                      avg_d_RH           73.0       68.0       64.0       74.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          14.1       12.8       10.6       11.1
#                      avg_d_wind         13.5       14.4        9.8       10.1
# (-40.9006, 174.886)  data               52.0      102.0      102.0      155.0
#                      avg_d_RH           77.0       76.0       75.0       56.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          15.9       18.7       17.3       13.5
#                      avg_d_wind         19.2       33.1       26.2       25.2
# (-38.4161, -63.6167) data              158.0      266.0      301.0      387.0
#                      avg_d_RH           52.0       43.0       50.0       46.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          19.3       20.5       21.4       22.0
#                      avg_d_wind          6.6        4.9        6.0        8.5
# (-37.8136, 144.9631) data              229.0      355.0      355.0      411.0
#                      avg_d_RH           75.0       79.0       63.0       68.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          15.0       14.6       14.5       13.2
#                      avg_d_wind         13.8       19.1       18.1       12.1
# (-35.6751, -71.543)  data              537.0      632.0      746.0      922.0
#                      avg_d_RH           78.0       62.0       65.0       79.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          13.6       16.6       16.9       17.8
#                      avg_d_wind         11.6       12.2       14.9        8.7
# (-35.4735, 149.0124) data                9.0       19.0       32.0       39.0
#                      avg_d_RH           61.0       73.0       59.0       71.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          16.2       15.1       15.6       15.8
#                      avg_d_wind          8.3       10.0       13.6        6.8
# ...                                      ...        ...        ...        ...
# (60.0, 90.0)         data              306.0      367.0      438.0      495.0
#                      avg_d_RH           49.0       46.0       59.0       60.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           3.9        6.9       -4.2      -11.7
#                      avg_d_wind         20.2       19.8       29.1       13.1
# (60.472, 8.4689)     data             2118.0     2385.0     2621.0     2863.0
#                      avg_d_RH           68.0       61.0       49.0       66.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          -2.7        0.0        2.5        3.7
#                      avg_d_wind         10.1       12.0       16.7       13.4
# (61.8926, -6.9118)   data               92.0      115.0      118.0      122.0
#                      avg_d_RH           77.0       75.0       80.0       87.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           5.5        6.0        6.8        8.3
#                      avg_d_wind         32.4       37.1       46.7       39.9
# (63.0, 16.0)         data             1763.0     1934.0     2046.0     2286.0
#                      avg_d_RH           73.0       55.0       56.0       54.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          -2.1       -1.6        0.3        3.6
#                      avg_d_wind         14.6       14.1       20.1       26.1
# (64.0, 26.0)         data              523.0      626.0      700.0      792.0
#                      avg_d_RH           69.0       55.0       58.0       62.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          -9.1       -6.0        0.0        2.5
#                      avg_d_wind          5.8       12.8       17.4       21.5
# (64.9631, -19.0208)  data              473.0      568.0      588.0      648.0
#                      avg_d_RH           67.0       66.0       69.0       63.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           2.4        1.9        3.0        1.6
#                      avg_d_wind         29.4       27.8       35.3       25.6
#
#                                    3/25/2020  3/26/2020  3/27/2020
# coordinate           information
# (-41.4545, 145.9707) data               36.0       47.0       47.0
#                      avg_d_RH           74.0       68.0       74.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp          12.3       11.2       13.5
#                      avg_d_wind          8.5       15.2        6.8
# (-40.9006, 174.886)  data              205.0      283.0      368.0
#                      avg_d_RH           71.0       70.0       86.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp          14.6       16.6       15.0
#                      avg_d_wind         19.3       34.7       27.4
# (-38.4161, -63.6167) data              387.0      502.0      589.0
#                      avg_d_RH           55.0       45.0       56.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp          19.6       22.4       22.5
#                      avg_d_wind          5.2       11.8        4.3
# (-37.8136, 144.9631) data              466.0      520.0      574.0
#                      avg_d_RH           67.0       78.0       73.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp          14.6       15.4       17.3
#                      avg_d_wind         16.9       15.5       11.3
# (-35.6751, -71.543)  data             1142.0     1306.0     1610.0
#                      avg_d_RH           73.0       69.0       91.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp          20.1       19.1       14.5
#                      avg_d_wind         11.2        7.8        5.2
# (-35.4735, 149.0124) data               39.0       53.0       62.0
#                      avg_d_RH           80.0       64.0       74.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp          17.2       14.9       15.6
#                      avg_d_wind         11.9       17.1       10.6
# ...                                      ...        ...        ...
# (60.0, 90.0)         data              658.0      840.0     1036.0
#                      avg_d_RH           64.0       58.0       25.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp          -8.2       -2.6        2.5
#                      avg_d_wind         22.4       20.6       20.2
# (60.472, 8.4689)     data             3084.0     3369.0     3755.0
#                      avg_d_RH           88.0       95.0       83.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp           4.3        2.7        2.4
#                      avg_d_wind         13.7        4.8       11.7
# (61.8926, -6.9118)   data              132.0      140.0      144.0
#                      avg_d_RH           86.0       81.0       77.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp           6.6        6.4        6.6
#                      avg_d_wind         15.5       19.0       21.6
# (63.0, 16.0)         data             2526.0     2840.0     3069.0
#                      avg_d_RH           70.0       71.0       71.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp           4.1        3.6        2.5
#                      avg_d_wind         25.1        9.1        9.9
# (64.0, 26.0)         data              880.0      958.0     1041.0
#                      avg_d_RH           61.0       72.0       75.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp           4.4        2.5        3.6
#                      avg_d_wind         20.9       15.9       15.4
# (64.9631, -19.0208)  data              737.0      802.0      890.0
#                      avg_d_RH           62.0       59.0       64.0
#                      avg_d_precip        0.0        0.0        0.0
#                      avg_d_tmp           1.6        1.5       -0.9
#                      avg_d_wind         16.6       24.8       12.5
#
# [895 rows x 82 columns]

# %% [markdown]
# Import gdp per country and per state data

# %%
# original_columns = list(hopkins_conf.columns)
# original_columns.append('GDP')
# original_columns.append('Urbanization')

# # print(original_columns)

# prev_GDP = original_columns.index('GDP')
# prev_urban = original_columns.index('Urbanization')
# new_GDP = original_columns.index('Country_Region') + 1
# new_urban = new_GDP + 1
# original_columns.insert(new_GDP, original_columns.pop(prev_GDP))
# original_columns.insert(new_urban, original_columns.pop(prev_urban))

# print (original_columns)

# %%
# https://data.worldbank.org/indicator/NY.GDP.PCAP.CD  - in current USD
gdp_country_path = '../external_datasets/GDP_per_capita_countries.csv'
# https://en.wikipedia.org/wiki/List_of_U.S._states_by_GDP_per_capita#cite_note-3
gdp_state_path = '../external_datasets/GDP_per_capita_states.csv'
# source: http://wdi.worldbank.org/table/4.2# (2018)
urban_country_path = '../external_datasets/urbanization_data.csv'
# source: US census bureau (most updated was is from 2010)
urban_state_path = '../external_datasets/urbanization_states.csv'

# %%
# # source: http://wdi.worldbank.org/table/4.2# (2018)
gdp_country = pd.read_csv(gdp_country_path)
gdp_country.columns=['Country_Region', 'GDP']

# # source: https://www.statista.com/statistics/248023/us-gross-domestic-product-gdp-by-state/ 
gdp_state = pd.read_csv(gdp_state_path)
gdp_state.columns = ['Province_State', 'GDP']

# %%
# gdp_state.columns

# %% [markdown]
# Import urbanization per country and per state data

# %%
# source: http://wdi.worldbank.org/table/4.2# (2018)
urban_country = pd.read_csv(urban_country_path)
urban_country.columns=['Country_Region', 'Urbanization']

# source: US census bureau (most updated was is from 2010)
urban_state = pd.read_csv(urban_state_path)
urban_state.columns = ['Province_State', 'Urbanization']

# %% [markdown]
# data preprocessing functions

# %%
def standardize_original_names(df):
    df = df.replace({'Cape Verde': 'Cabo Verde',
                     'Timor-Leste': 'East Timor',
                     'Timor Leste': 'East Timor',
                     'Taiwan*': 'Taiwan'
                    })
    return df

# tableau_conf_data = standardize_original_names(tableau_conf_data)
# tableau_death_data = standardize_original_names(tableau_death_data)
# hopkins_conf_data = standardize_original_names(hopkins_conf_data)
# hopkins_death_data = standardize_original_names(hopkins_death_data)

# %%
index_dict = {
    'gdp_country': 'Country_Region',
    'gdp_state': 'Province_State',
    'urban_country': 'Country_Region',
    'urban_state': 'Province_State'    
}

    
# # setting indices for more convenient access in lambda funtion in add_gdp_urban function
# gdp_country = gdp_country.set_index(index_dict['gdp_country'])
# gdp_state = gdp_state.set_index(index_dict['gdp_state'])
# urban_country = urban_country.set_index(index_dict['urban_country'])
# urban_state = urban_state.set_index(index_dict['urban_state'])

# %%
def standardize_external_names(external_df):
    external_df = external_df.replace({
        'United States': 'US',
        'Iran, Islamic Rep.': 'Iran',
        'Congo, Rep.': 'Congo (Brazzaville)',
        'Congo, Dem. Rep.': 'Congo (Kinshasa)',
        'St. Lucia': 'Saint Lucia',
        'Czech Republic':'Czechia',
        'Kyrgyz Republic': 'Kyrgyzstan',
        'Egypt, Arab Rep.': 'Egypt',
        'Syrian Arab Republic': 'Syria',
    #     'Cabo Verde': 'Cape Verde',
        'Brunei Darussalam': 'Brunei',
        'Slovak Republic': 'Slovakia',
        'Korea, Rep.': 'Korea, South',
        'Timor Leste': 'East Timor',
        'St. Vincent and the Grenadines': 'Saint Vincent and the Grenadines',
        })
    return external_df

# gdp_country = standardize_external_names(gdp_country)
# urban_country = standardize_external_names(urban_country)

# %% [markdown]
# this is where the magic happens

# %%
def add_gdp_urban(original, gdp_country, gdp_state, urban_country, urban_state):
    
    original = standardize_original_names(original)

    gdp_country = standardize_external_names(gdp_country)
    urban_country = standardize_external_names(urban_country)
    
    # setting indices for more convenient access in lambda funtion below
    gdp_country = gdp_country.set_index(index_dict['gdp_country'])
    gdp_state = gdp_state.set_index(index_dict['gdp_state'])
    urban_country = urban_country.set_index(index_dict['urban_country'])
    urban_state = urban_state.set_index(index_dict['urban_state'])
    
    # if there is no state data, take country data, and if there is also no country data, put NaN
    original['GDP'] = original.apply(lambda row: gdp_state.loc[row['Province_State'],'GDP'] if row['Province_State'] in list(gdp_state.index) else (gdp_country.loc[row['Country_Region'],'GDP'] if row['Country_Region'] in list(gdp_country.index) else np.NaN), axis=1) 
    original['Urbanization'] = original.apply(lambda row: urban_state.loc[row['Province_State'],'Urbanization'] if row['Province_State'] in list(urban_state.index) else (urban_country.loc[row['Country_Region'],'Urbanization'] if row['Country_Region'] in list(urban_country.index) else np.NaN), axis=1)
    
    new_columns = list(original.columns)
#     print(new_columns)
    prev_GDP = new_columns.index('GDP')
    prev_urban = new_columns.index('Urbanization')

#     print(prev_GDP)
    new_GDP = new_columns.index('Country_Region') + 1
#     print(new_GDP)
    new_urban = new_GDP + 1
    print(new_urban)
#     print(len(new_columns))
    new_columns.insert(new_GDP, new_columns.pop(prev_GDP))
    
    new_columns.insert(new_urban, new_columns.pop(prev_urban))
    
    return original[new_columns]
#     return original

# %%
# pd.set_option('display.max_columns', None)

# new_tableau_conf = add_gdp_urban(tableau_conf_data, gdp_country, gdp_state, urban_country, urban_state)
# new_tableau_conf.head(5)

# %%
# new_tableau_conf.to_csv('../augmented_datasets/tableau_conf_augmented_gdp_urban.csv')

# %%
# new_tableau_death = add_gdp_urban(tableau_death_data, gdp_country, gdp_state, urban_country, urban_state)

# %%
# new_tableau_death.to_csv('../augmented_datasets/tableau_death_augmented_gdp_urban.csv')

# %%
new_hopkins_conf = add_gdp_urban(hopkins_conf, gdp_country, gdp_state, urban_country, urban_state)
new_hopkins_conf
# Out:
# 3
#                                                  Province_State  \
# coordinate           information
# (-41.4545, 145.9707) data                              Tasmania
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-40.9006, 174.886)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-38.4161, -63.6167) data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-37.8136, 144.9631) data                              Victoria
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-35.6751, -71.543)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-35.4735, 149.0124) data          Australian Capital Territory
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# ...                                                         ...
# (60.0, 90.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (60.472, 8.4689)     data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (61.8926, -6.9118)   data                         Faroe Islands
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (63.0, 16.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (64.0, 26.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (64.9631, -19.0208)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
#
#                                   Country_Region          GDP  Urbanization  \
# coordinate           information
# (-41.4545, 145.9707) data              Australia  57373.68668        86.012
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-40.9006, 174.886)  data            New Zealand  41945.33167        86.538
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-38.4161, -63.6167) data              Argentina  11683.94962        91.870
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-37.8136, 144.9631) data              Australia  57373.68668        86.012
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-35.6751, -71.543)  data                  Chile  15923.35874        87.564
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-35.4735, 149.0124) data              Australia  57373.68668        86.012
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# ...                                          ...          ...           ...
# (60.0, 90.0)         data                 Russia          NaN           NaN
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (60.472, 8.4689)     data                 Norway  81697.24598        82.248
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (61.8926, -6.9118)   data                Denmark  61350.34791        87.874
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (63.0, 16.0)         data                 Sweden  54608.36025        87.431
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (64.0, 26.0)         data                Finland  50152.34014        85.382
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (64.9631, -19.0208)  data                Iceland  73191.11632        93.813
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
#
#                                    avg_m_tmp   avg_m_RH  avg_m_precip  \
# coordinate           information
# (-41.4545, 145.9707) data          15.466667  68.818182           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-40.9006, 174.886)  data          17.754545  74.772727           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-38.4161, -63.6167) data          22.995455  43.984848           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-37.8136, 144.9631) data          18.592424  70.818182           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-35.6751, -71.543)  data          20.348485  56.090909           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-35.4735, 149.0124) data          19.777273  62.848485           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# ...                                      ...        ...           ...
# (60.0, 90.0)         data          -7.101515  71.909091           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (60.472, 8.4689)     data          -0.006061  82.530303           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (61.8926, -6.9118)   data           3.506061  81.696970           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (63.0, 16.0)         data          -1.584848  79.212121           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (64.0, 26.0)         data          -4.256250  83.234375           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (64.9631, -19.0208)  data          -2.230159  78.571429           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
#
#                                    avg_m_wind  Max_Cases   first_7    ...      \
# coordinate           information                                      ...
# (-41.4545, 145.9707) data           18.469697       47.0  1.333333    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-40.9006, 174.886)  data           26.777273      368.0  6.750000    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-38.4161, -63.6167) data           10.572727      589.0  2.129032    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-37.8136, 144.9631) data           17.498485      574.0  2.361111    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-35.6751, -71.543)  data           12.646970     1610.0  3.077419    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-35.4735, 149.0124) data           14.260606       62.0  8.750000    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# ...                                       ...        ...       ...    ...
# (60.0, 90.0)         data           12.530303     1036.0  3.288136    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (60.472, 8.4689)     data           12.275758     3755.0  4.956098    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (61.8926, -6.9118)   data           23.180303      144.0  7.888889    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (63.0, 16.0)         data           17.298485     3069.0  4.055901    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (64.0, 26.0)         data           15.381250     1041.0  4.440678    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (64.9631, -19.0208)  data           16.523810      890.0  1.680000    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
#
#                                   3/18/2020 3/19/2020 3/20/2020  3/21/2020  \
# coordinate           information
# (-41.4545, 145.9707) data              10.0      10.0      10.0       16.0
#                      avg_d_RH          82.0      93.0      81.0       73.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         16.5      14.9      14.9       14.1
#                      avg_d_wind        18.6       8.4      21.2       13.5
# (-40.9006, 174.886)  data              20.0      28.0      39.0       52.0
#                      avg_d_RH          60.0      72.0      70.0       77.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         14.1      17.0      16.4       15.9
#                      avg_d_wind        21.4      35.2      25.5       19.2
# (-38.4161, -63.6167) data              79.0      97.0     128.0      158.0
#                      avg_d_RH          62.0      47.0      52.0       52.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         19.4      20.2      18.5       19.3
#                      avg_d_wind         5.6       9.5       4.0        6.6
# (-37.8136, 144.9631) data             121.0     121.0     121.0      229.0
#                      avg_d_RH          44.0      44.0      64.0       75.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         23.6      25.9      18.2       15.0
#                      avg_d_wind        25.6      20.3      22.6       13.8
# (-35.6751, -71.543)  data             238.0     238.0     434.0      537.0
#                      avg_d_RH          63.0      57.0      55.0       78.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         18.1      18.0      16.9       13.6
#                      avg_d_wind        10.2      11.2       9.3       11.6
# (-35.4735, 149.0124) data               3.0       4.0       6.0        9.0
#                      avg_d_RH          67.0      59.0      44.0       61.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         16.2      19.8      22.0       16.2
#                      avg_d_wind        11.0       8.9      23.1        8.3
# ...                                     ...       ...       ...        ...
# (60.0, 90.0)         data             147.0     199.0     253.0      306.0
#                      avg_d_RH          61.0      71.0      76.0       49.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         -0.2      -1.5      -0.8        3.9
#                      avg_d_wind        25.4      19.6      14.8       20.2
# (60.472, 8.4689)     data            1550.0    1746.0    1914.0     2118.0
#                      avg_d_RH          99.0      93.0      75.0       68.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         -0.6       0.6      -0.7       -2.7
#                      avg_d_wind         7.4       5.9       7.3       10.1
# (61.8926, -6.9118)   data              58.0      72.0      80.0       92.0
#                      avg_d_RH          76.0      78.0      74.0       77.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp          4.0       2.2       2.2        5.5
#                      avg_d_wind        17.8      15.0      15.0       32.4
# (63.0, 16.0)         data            1279.0    1439.0    1639.0     1763.0
#                      avg_d_RH          66.0      74.0      76.0       73.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp          1.2      -0.1      -4.1       -2.1
#                      avg_d_wind        12.8      29.0      17.8       14.6
# (64.0, 26.0)         data             336.0     400.0     450.0      523.0
#                      avg_d_RH          80.0      74.0      65.0       69.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp          0.9      -1.4      -7.5       -9.1
#                      avg_d_wind        15.4      11.8      11.1        5.8
# (64.9631, -19.0208)  data             250.0     330.0     409.0      473.0
#                      avg_d_RH          77.0      75.0      67.0       67.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         -1.0      -6.0       2.3        2.4
#                      avg_d_wind        13.4      13.6      36.3       29.4
#
#                                    3/22/2020  3/23/2020  3/24/2020  3/25/2020  \
# coordinate           information
# (-41.4545, 145.9707) data               22.0       28.0       28.0       36.0
#                      avg_d_RH           68.0       64.0       74.0       74.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          12.8       10.6       11.1       12.3
#                      avg_d_wind         14.4        9.8       10.1        8.5
# (-40.9006, 174.886)  data              102.0      102.0      155.0      205.0
#                      avg_d_RH           76.0       75.0       56.0       71.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          18.7       17.3       13.5       14.6
#                      avg_d_wind         33.1       26.2       25.2       19.3
# (-38.4161, -63.6167) data              266.0      301.0      387.0      387.0
#                      avg_d_RH           43.0       50.0       46.0       55.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          20.5       21.4       22.0       19.6
#                      avg_d_wind          4.9        6.0        8.5        5.2
# (-37.8136, 144.9631) data              355.0      355.0      411.0      466.0
#                      avg_d_RH           79.0       63.0       68.0       67.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          14.6       14.5       13.2       14.6
#                      avg_d_wind         19.1       18.1       12.1       16.9
# (-35.6751, -71.543)  data              632.0      746.0      922.0     1142.0
#                      avg_d_RH           62.0       65.0       79.0       73.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          16.6       16.9       17.8       20.1
#                      avg_d_wind         12.2       14.9        8.7       11.2
# (-35.4735, 149.0124) data               19.0       32.0       39.0       39.0
#                      avg_d_RH           73.0       59.0       71.0       80.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          15.1       15.6       15.8       17.2
#                      avg_d_wind         10.0       13.6        6.8       11.9
# ...                                      ...        ...        ...        ...
# (60.0, 90.0)         data              367.0      438.0      495.0      658.0
#                      avg_d_RH           46.0       59.0       60.0       64.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           6.9       -4.2      -11.7       -8.2
#                      avg_d_wind         19.8       29.1       13.1       22.4
# (60.472, 8.4689)     data             2385.0     2621.0     2863.0     3084.0
#                      avg_d_RH           61.0       49.0       66.0       88.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           0.0        2.5        3.7        4.3
#                      avg_d_wind         12.0       16.7       13.4       13.7
# (61.8926, -6.9118)   data              115.0      118.0      122.0      132.0
#                      avg_d_RH           75.0       80.0       87.0       86.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           6.0        6.8        8.3        6.6
#                      avg_d_wind         37.1       46.7       39.9       15.5
# (63.0, 16.0)         data             1934.0     2046.0     2286.0     2526.0
#                      avg_d_RH           55.0       56.0       54.0       70.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          -1.6        0.3        3.6        4.1
#                      avg_d_wind         14.1       20.1       26.1       25.1
# (64.0, 26.0)         data              626.0      700.0      792.0      880.0
#                      avg_d_RH           55.0       58.0       62.0       61.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          -6.0        0.0        2.5        4.4
#                      avg_d_wind         12.8       17.4       21.5       20.9
# (64.9631, -19.0208)  data              568.0      588.0      648.0      737.0
#                      avg_d_RH           66.0       69.0       63.0       62.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           1.9        3.0        1.6        1.6
#                      avg_d_wind         27.8       35.3       25.6       16.6
#
#                                    3/26/2020  3/27/2020
# coordinate           information
# (-41.4545, 145.9707) data               47.0       47.0
#                      avg_d_RH           68.0       74.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          11.2       13.5
#                      avg_d_wind         15.2        6.8
# (-40.9006, 174.886)  data              283.0      368.0
#                      avg_d_RH           70.0       86.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          16.6       15.0
#                      avg_d_wind         34.7       27.4
# (-38.4161, -63.6167) data              502.0      589.0
#                      avg_d_RH           45.0       56.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          22.4       22.5
#                      avg_d_wind         11.8        4.3
# (-37.8136, 144.9631) data              520.0      574.0
#                      avg_d_RH           78.0       73.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          15.4       17.3
#                      avg_d_wind         15.5       11.3
# (-35.6751, -71.543)  data             1306.0     1610.0
#                      avg_d_RH           69.0       91.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          19.1       14.5
#                      avg_d_wind          7.8        5.2
# (-35.4735, 149.0124) data               53.0       62.0
#                      avg_d_RH           64.0       74.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          14.9       15.6
#                      avg_d_wind         17.1       10.6
# ...                                      ...        ...
# (60.0, 90.0)         data              840.0     1036.0
#                      avg_d_RH           58.0       25.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          -2.6        2.5
#                      avg_d_wind         20.6       20.2
# (60.472, 8.4689)     data             3369.0     3755.0
#                      avg_d_RH           95.0       83.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           2.7        2.4
#                      avg_d_wind          4.8       11.7
# (61.8926, -6.9118)   data              140.0      144.0
#                      avg_d_RH           81.0       77.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           6.4        6.6
#                      avg_d_wind         19.0       21.6
# (63.0, 16.0)         data             2840.0     3069.0
#                      avg_d_RH           71.0       71.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           3.6        2.5
#                      avg_d_wind          9.1        9.9
# (64.0, 26.0)         data              958.0     1041.0
#                      avg_d_RH           72.0       75.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           2.5        3.6
#                      avg_d_wind         15.9       15.4
# (64.9631, -19.0208)  data              802.0      890.0
#                      avg_d_RH           59.0       64.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           1.5       -0.9
#                      avg_d_wind         24.8       12.5
#
# [895 rows x 84 columns]

# %%
with open(RESULT_PATH, 'wb') as file:
    pickle.dump(new_hopkins_conf, file)

# %%
test = pd.DataFrame()
with open(RESULT_PATH, 'rb') as file:
    test = pickle.load(file)

test
# Out:
#                                                  Province_State  \
# coordinate           information
# (-41.4545, 145.9707) data                              Tasmania
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-40.9006, 174.886)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-38.4161, -63.6167) data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-37.8136, 144.9631) data                              Victoria
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-35.6751, -71.543)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (-35.4735, 149.0124) data          Australian Capital Territory
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# ...                                                         ...
# (60.0, 90.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (60.472, 8.4689)     data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (61.8926, -6.9118)   data                         Faroe Islands
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (63.0, 16.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (64.0, 26.0)         data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
# (64.9631, -19.0208)  data                                   NaN
#                      avg_d_RH                               NaN
#                      avg_d_precip                           NaN
#                      avg_d_tmp                              NaN
#                      avg_d_wind                             NaN
#
#                                   Country_Region          GDP  Urbanization  \
# coordinate           information
# (-41.4545, 145.9707) data              Australia  57373.68668        86.012
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-40.9006, 174.886)  data            New Zealand  41945.33167        86.538
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-38.4161, -63.6167) data              Argentina  11683.94962        91.870
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-37.8136, 144.9631) data              Australia  57373.68668        86.012
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-35.6751, -71.543)  data                  Chile  15923.35874        87.564
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (-35.4735, 149.0124) data              Australia  57373.68668        86.012
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# ...                                          ...          ...           ...
# (60.0, 90.0)         data                 Russia          NaN           NaN
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (60.472, 8.4689)     data                 Norway  81697.24598        82.248
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (61.8926, -6.9118)   data                Denmark  61350.34791        87.874
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (63.0, 16.0)         data                 Sweden  54608.36025        87.431
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (64.0, 26.0)         data                Finland  50152.34014        85.382
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
# (64.9631, -19.0208)  data                Iceland  73191.11632        93.813
#                      avg_d_RH                NaN          NaN           NaN
#                      avg_d_precip            NaN          NaN           NaN
#                      avg_d_tmp               NaN          NaN           NaN
#                      avg_d_wind              NaN          NaN           NaN
#
#                                    avg_m_tmp   avg_m_RH  avg_m_precip  \
# coordinate           information
# (-41.4545, 145.9707) data          15.466667  68.818182           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-40.9006, 174.886)  data          17.754545  74.772727           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-38.4161, -63.6167) data          22.995455  43.984848           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-37.8136, 144.9631) data          18.592424  70.818182           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-35.6751, -71.543)  data          20.348485  56.090909           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (-35.4735, 149.0124) data          19.777273  62.848485           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# ...                                      ...        ...           ...
# (60.0, 90.0)         data          -7.101515  71.909091           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (60.472, 8.4689)     data          -0.006061  82.530303           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (61.8926, -6.9118)   data           3.506061  81.696970           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (63.0, 16.0)         data          -1.584848  79.212121           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (64.0, 26.0)         data          -4.256250  83.234375           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
# (64.9631, -19.0208)  data          -2.230159  78.571429           0.0
#                      avg_d_RH            NaN        NaN           NaN
#                      avg_d_precip        NaN        NaN           NaN
#                      avg_d_tmp           NaN        NaN           NaN
#                      avg_d_wind          NaN        NaN           NaN
#
#                                    avg_m_wind  Max_Cases   first_7    ...      \
# coordinate           information                                      ...
# (-41.4545, 145.9707) data           18.469697       47.0  1.333333    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-40.9006, 174.886)  data           26.777273      368.0  6.750000    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-38.4161, -63.6167) data           10.572727      589.0  2.129032    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-37.8136, 144.9631) data           17.498485      574.0  2.361111    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-35.6751, -71.543)  data           12.646970     1610.0  3.077419    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (-35.4735, 149.0124) data           14.260606       62.0  8.750000    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# ...                                       ...        ...       ...    ...
# (60.0, 90.0)         data           12.530303     1036.0  3.288136    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (60.472, 8.4689)     data           12.275758     3755.0  4.956098    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (61.8926, -6.9118)   data           23.180303      144.0  7.888889    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (63.0, 16.0)         data           17.298485     3069.0  4.055901    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (64.0, 26.0)         data           15.381250     1041.0  4.440678    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
# (64.9631, -19.0208)  data           16.523810      890.0  1.680000    ...
#                      avg_d_RH             NaN        NaN       NaN    ...
#                      avg_d_precip         NaN        NaN       NaN    ...
#                      avg_d_tmp            NaN        NaN       NaN    ...
#                      avg_d_wind           NaN        NaN       NaN    ...
#
#                                   3/18/2020 3/19/2020 3/20/2020  3/21/2020  \
# coordinate           information
# (-41.4545, 145.9707) data              10.0      10.0      10.0       16.0
#                      avg_d_RH          82.0      93.0      81.0       73.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         16.5      14.9      14.9       14.1
#                      avg_d_wind        18.6       8.4      21.2       13.5
# (-40.9006, 174.886)  data              20.0      28.0      39.0       52.0
#                      avg_d_RH          60.0      72.0      70.0       77.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         14.1      17.0      16.4       15.9
#                      avg_d_wind        21.4      35.2      25.5       19.2
# (-38.4161, -63.6167) data              79.0      97.0     128.0      158.0
#                      avg_d_RH          62.0      47.0      52.0       52.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         19.4      20.2      18.5       19.3
#                      avg_d_wind         5.6       9.5       4.0        6.6
# (-37.8136, 144.9631) data             121.0     121.0     121.0      229.0
#                      avg_d_RH          44.0      44.0      64.0       75.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         23.6      25.9      18.2       15.0
#                      avg_d_wind        25.6      20.3      22.6       13.8
# (-35.6751, -71.543)  data             238.0     238.0     434.0      537.0
#                      avg_d_RH          63.0      57.0      55.0       78.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         18.1      18.0      16.9       13.6
#                      avg_d_wind        10.2      11.2       9.3       11.6
# (-35.4735, 149.0124) data               3.0       4.0       6.0        9.0
#                      avg_d_RH          67.0      59.0      44.0       61.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         16.2      19.8      22.0       16.2
#                      avg_d_wind        11.0       8.9      23.1        8.3
# ...                                     ...       ...       ...        ...
# (60.0, 90.0)         data             147.0     199.0     253.0      306.0
#                      avg_d_RH          61.0      71.0      76.0       49.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         -0.2      -1.5      -0.8        3.9
#                      avg_d_wind        25.4      19.6      14.8       20.2
# (60.472, 8.4689)     data            1550.0    1746.0    1914.0     2118.0
#                      avg_d_RH          99.0      93.0      75.0       68.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         -0.6       0.6      -0.7       -2.7
#                      avg_d_wind         7.4       5.9       7.3       10.1
# (61.8926, -6.9118)   data              58.0      72.0      80.0       92.0
#                      avg_d_RH          76.0      78.0      74.0       77.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp          4.0       2.2       2.2        5.5
#                      avg_d_wind        17.8      15.0      15.0       32.4
# (63.0, 16.0)         data            1279.0    1439.0    1639.0     1763.0
#                      avg_d_RH          66.0      74.0      76.0       73.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp          1.2      -0.1      -4.1       -2.1
#                      avg_d_wind        12.8      29.0      17.8       14.6
# (64.0, 26.0)         data             336.0     400.0     450.0      523.0
#                      avg_d_RH          80.0      74.0      65.0       69.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp          0.9      -1.4      -7.5       -9.1
#                      avg_d_wind        15.4      11.8      11.1        5.8
# (64.9631, -19.0208)  data             250.0     330.0     409.0      473.0
#                      avg_d_RH          77.0      75.0      67.0       67.0
#                      avg_d_precip       0.0       0.0       0.0        0.0
#                      avg_d_tmp         -1.0      -6.0       2.3        2.4
#                      avg_d_wind        13.4      13.6      36.3       29.4
#
#                                    3/22/2020  3/23/2020  3/24/2020  3/25/2020  \
# coordinate           information
# (-41.4545, 145.9707) data               22.0       28.0       28.0       36.0
#                      avg_d_RH           68.0       64.0       74.0       74.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          12.8       10.6       11.1       12.3
#                      avg_d_wind         14.4        9.8       10.1        8.5
# (-40.9006, 174.886)  data              102.0      102.0      155.0      205.0
#                      avg_d_RH           76.0       75.0       56.0       71.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          18.7       17.3       13.5       14.6
#                      avg_d_wind         33.1       26.2       25.2       19.3
# (-38.4161, -63.6167) data              266.0      301.0      387.0      387.0
#                      avg_d_RH           43.0       50.0       46.0       55.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          20.5       21.4       22.0       19.6
#                      avg_d_wind          4.9        6.0        8.5        5.2
# (-37.8136, 144.9631) data              355.0      355.0      411.0      466.0
#                      avg_d_RH           79.0       63.0       68.0       67.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          14.6       14.5       13.2       14.6
#                      avg_d_wind         19.1       18.1       12.1       16.9
# (-35.6751, -71.543)  data              632.0      746.0      922.0     1142.0
#                      avg_d_RH           62.0       65.0       79.0       73.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          16.6       16.9       17.8       20.1
#                      avg_d_wind         12.2       14.9        8.7       11.2
# (-35.4735, 149.0124) data               19.0       32.0       39.0       39.0
#                      avg_d_RH           73.0       59.0       71.0       80.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          15.1       15.6       15.8       17.2
#                      avg_d_wind         10.0       13.6        6.8       11.9
# ...                                      ...        ...        ...        ...
# (60.0, 90.0)         data              367.0      438.0      495.0      658.0
#                      avg_d_RH           46.0       59.0       60.0       64.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           6.9       -4.2      -11.7       -8.2
#                      avg_d_wind         19.8       29.1       13.1       22.4
# (60.472, 8.4689)     data             2385.0     2621.0     2863.0     3084.0
#                      avg_d_RH           61.0       49.0       66.0       88.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           0.0        2.5        3.7        4.3
#                      avg_d_wind         12.0       16.7       13.4       13.7
# (61.8926, -6.9118)   data              115.0      118.0      122.0      132.0
#                      avg_d_RH           75.0       80.0       87.0       86.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           6.0        6.8        8.3        6.6
#                      avg_d_wind         37.1       46.7       39.9       15.5
# (63.0, 16.0)         data             1934.0     2046.0     2286.0     2526.0
#                      avg_d_RH           55.0       56.0       54.0       70.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          -1.6        0.3        3.6        4.1
#                      avg_d_wind         14.1       20.1       26.1       25.1
# (64.0, 26.0)         data              626.0      700.0      792.0      880.0
#                      avg_d_RH           55.0       58.0       62.0       61.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp          -6.0        0.0        2.5        4.4
#                      avg_d_wind         12.8       17.4       21.5       20.9
# (64.9631, -19.0208)  data              568.0      588.0      648.0      737.0
#                      avg_d_RH           66.0       69.0       63.0       62.0
#                      avg_d_precip        0.0        0.0        0.0        0.0
#                      avg_d_tmp           1.9        3.0        1.6        1.6
#                      avg_d_wind         27.8       35.3       25.6       16.6
#
#                                    3/26/2020  3/27/2020
# coordinate           information
# (-41.4545, 145.9707) data               47.0       47.0
#                      avg_d_RH           68.0       74.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          11.2       13.5
#                      avg_d_wind         15.2        6.8
# (-40.9006, 174.886)  data              283.0      368.0
#                      avg_d_RH           70.0       86.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          16.6       15.0
#                      avg_d_wind         34.7       27.4
# (-38.4161, -63.6167) data              502.0      589.0
#                      avg_d_RH           45.0       56.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          22.4       22.5
#                      avg_d_wind         11.8        4.3
# (-37.8136, 144.9631) data              520.0      574.0
#                      avg_d_RH           78.0       73.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          15.4       17.3
#                      avg_d_wind         15.5       11.3
# (-35.6751, -71.543)  data             1306.0     1610.0
#                      avg_d_RH           69.0       91.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          19.1       14.5
#                      avg_d_wind          7.8        5.2
# (-35.4735, 149.0124) data               53.0       62.0
#                      avg_d_RH           64.0       74.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          14.9       15.6
#                      avg_d_wind         17.1       10.6
# ...                                      ...        ...
# (60.0, 90.0)         data              840.0     1036.0
#                      avg_d_RH           58.0       25.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp          -2.6        2.5
#                      avg_d_wind         20.6       20.2
# (60.472, 8.4689)     data             3369.0     3755.0
#                      avg_d_RH           95.0       83.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           2.7        2.4
#                      avg_d_wind          4.8       11.7
# (61.8926, -6.9118)   data              140.0      144.0
#                      avg_d_RH           81.0       77.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           6.4        6.6
#                      avg_d_wind         19.0       21.6
# (63.0, 16.0)         data             2840.0     3069.0
#                      avg_d_RH           71.0       71.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           3.6        2.5
#                      avg_d_wind          9.1        9.9
# (64.0, 26.0)         data              958.0     1041.0
#                      avg_d_RH           72.0       75.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           2.5        3.6
#                      avg_d_wind         15.9       15.4
# (64.9631, -19.0208)  data              802.0      890.0
#                      avg_d_RH           59.0       64.0
#                      avg_d_precip        0.0        0.0
#                      avg_d_tmp           1.5       -0.9
#                      avg_d_wind         24.8       12.5
#
# [895 rows x 84 columns]

# %%
# new_hopkins_conf.to_csv('../augmented_datasets/hopkins_conf_augmented_gdp_urban.csv')

# %%
new_hopkins_death = add_gdp_urban(hopkins_conf, gdp_country, gdp_state, urban_country, urban_state)
# Out:
# 3

# %%
# new_hopkins_death.to_csv('../augmented_datasets/hopkins_death_augmented_gdp_urban.csv')
